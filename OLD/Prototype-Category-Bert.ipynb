# %% [markdown]
# ### Prototype code to scrape the top headlines and their corresponding article text from News API

# %%
import pandas as pd
import json

# %%
import pprint
import requests

# %%
# API Key for News API
secret = 'e3eca7fe616e4895bbd8c162ec9d567d'

# %%
# Define the endpoint to extract all the top headlines 
url = 'https://newsapi.org/v2/top-headlines?'

# %%
# Specify the query and number of returns - Limit the headlines to country US, for now
parameters = {
    'country': 'us',
    'category': 'business',
    'pageSize': 100,
    'apiKey': secret 
}

# %%
# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Francis Scarcella fscarcella@dailyitem.com',
#                'content': 'HUMMELS WHARF Two people are dead following a '
#                           'shooting, but there is no threat to the public at '
#                           'this time, according to Pennsylvania state '
#                           'police.\r\n'
#                           'Trooper Mark Reasner, a state police spokesman '
#                           'from… [+791 chars]',
#                'description': 'HUMMELS WHARF — Two people are dead following a '
#                               'shooting, but there is no threat to the public '
#                               'at this time, according to Pennsylvania state '
#                               'police.',
#                'publishedAt': '2020-07-11T02:00:00Z',
#                'source': {'id': None, 'name': 'Sunbury Daily Item'},
#                'title': 'UPDATE Two people reported dead; no threat to public; '
#                         'Monroe Marketplace evacuated - Sunbury Daily Item',
#                'url': 'https://www.dailyitem.com/news/update-state-police-two-dead-after-shooting-no-threat-to-public/article_22b78758-c30a-11ea-a658-57cb54b1c099.html',
#                'urlToImage': 'https://bloximages.chicago2.vip.townnews.com/dailyitem.com/content/tncms/assets/v3/editorial/e/09/e094e742-c31f-11ea-ae23-2fe4da32f69a/5f09269ab9f7e.image.jpg?resize=840%2C630'},
#               {'author': 'Lauren del Valle and Amir Vera, CNN',
#                'content': '(CNN)Three people have tested positive for '
#                           'coronavirus on Friday after taking a Delta Air '
#                           'Lines flight from Atlanta to Albany, New York.\r\n'
#                           'Flight 4815 left on July 6, a release from the '
#                           'Rensselaer Cou… [+733 chars]',
#                'description': 'The airline says it is following the guidance '
#                               'of local health care officials and the Centers '
#                               'for Disease Control and Prevention.',
#                'publishedAt': '2020-07-11T00:25:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': '3 people test positive for Covid-19 after taking '
#                         'Delta flight from Atlanta to Albany, airline says - '
#                         'CNN',
#                'url': 'https://www.cnn.com/2020/07/10/us/delta-air-lines-coronavirus-passengers/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200320135908-01-delta-airlines-file-super-tease.jpg'},
#               {'author': 'Josh Rivera',
#                'content': 'A group of\xa0Five Guys\xa0employees who refused to '
#                           'serve members of an\xa0Alabama police force\xa0have '
#                           'been fired or suspended.\r\n'
#                           'The incident\xa0took place on Tuesday when three '
#                           'officers of the Daphne Police Depar… [+2009 chars]',
#                'description': 'A group of Five Guys employees who refused to '
#                               'serve members of an Alabama police force have '
#                               'been fired or suspended, the chain says.',
#                'publishedAt': '2020-07-11T00:13:20Z',
#                'source': {'id': 'usa-today', 'name': 'USA Today'},
#                'title': 'Five Guys says employees who refused to serve police '
#                         'have been fired, suspended - USA TODAY',
#                'url': 'https://www.usatoday.com/story/money/food/2020/07/10/five-guys-fires-employees-after-they-refusing-police-service/5418419002/',
#                'urlToImage': 'https://www.gannett-cdn.com/-mm-/1e50282dc070fff1b625e35adf64c138151cb970/c=0-207-2046-1363/local/-/media/2018/12/03/USATODAY/USATODAY/636794405868612979-photo0jpg.jpg?width=1600&height=800&fit=crop'},
#               {'author': 'Catie Keck',
#                'content': 'Well, which do you want first?\r\n'
#                           'Lets start with the bad news about NBCs '
#                           'soon-to-launch streaming service Peacock. Citing '
#                           'sources familiar with the matter, CNBC reported '
#                           'Wednesday that the service is … [+2501 chars]',
#                'description': 'Well, which do you want first?',
#                'publishedAt': '2020-07-11T00:10:00Z',
#                'source': {'id': None, 'name': 'Gizmodo.com'},
#                'title': "I Have Good News and Bad News About NBC's Streaming "
#                         'Service Peacock - Gizmodo',
#                'url': 'https://gizmodo.com/i-have-good-news-and-bad-news-about-nbcs-streaming-serv-1844343727',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/eb4f7ndqukewnyh2ls4s.jpg'},
#               {'author': 'The Oregonian/OregonLive.com',
#                'content': 'MUJI U.S.A., a division of the Japanese retailer, '
#                           'announced Friday it had filed for bankruptcy '
#                           'organization. It blamed falling sales due to store '
#                           'closures during the coronavirus pandemic.\r\n'
#                           'The chain … [+1215 chars]',
#                'description': 'The retail outlet has a Portland store, which '
#                               'is open for business, in the old Meier & Frank '
#                               'Building downtown.',
#                'publishedAt': '2020-07-10T23:20:00Z',
#                'source': {'id': None, 'name': 'OregonLive'},
#                'title': 'MUJI U.S.A. files for bankruptcy, blames coronavirus '
#                         '- OregonLive',
#                'url': 'https://www.oregonlive.com/business/2020/07/muji-usa-files-for-bankruptcy-blames-coronavirus.html',
#                'urlToImage': 'https://www.oregonlive.com/resizer/pjarGAcVw1tuyrJUy8Iw0ok8Myg=/1280x0/smart/cloudfront-us-east-1.images.arcpublishing.com/advancelocal/RTSEZLX62VGDDPTKN4US2LCQIY.jpg'},
#               {'author': 'Steven Ewing',
#                'content': 'Holy moly, does this thing look cool.\r\n'
#                           'Bronco6G.com\r\n'
#                           'The 2021 Ford Bronco will finally make its debut on '
#                           'Monday, July 13. And with only days to go until the '
#                           'big unveiling, cue the leaked photos.\r\n'
#                           'The… [+1060 chars]',
#                'description': "Here's our best look yet at Ford's new two-door "
#                               'Bronco.',
#                'publishedAt': '2020-07-10T23:08:00Z',
#                'source': {'id': None, 'name': 'CNET'},
#                'title': "2021 Ford Bronco leaks ahead of Monday's debut - CNET",
#                'url': 'https://www.cnet.com/roadshow/news/2021-ford-bronco-leaked-photo/',
#                'urlToImage': 'https://cnet3.cbsistatic.com/img/fiXO1pTD_I5pqFUNOavvwmO8VZY=/2020/07/10/428452d7-02df-44ba-b16b-91b2dc6cc9f1/bronco-ogi.jpg'},
#               {'author': 'Cuyler Meade',
#                'content': 'Employees of all levels reportedly walked off the '
#                           'fabrication floor at the JBS Swift beef plant in '
#                           'Greeley on Friday afternoon as part of a dispute '
#                           'over pay for a certain group of plant workers.\r\n'
#                           'Spe… [+6013 chars]',
#                'description': 'Employees of all levels reportedly walked off '
#                               'the fabrication floor at the JBS Swift beef '
#                               'plant in Greeley on Friday afternoon as part of '
#                               'a dispute over pay for a certain group of plant '
#                               'workers. Sp…',
#                'publishedAt': '2020-07-10T22:59:27Z',
#                'source': {'id': None, 'name': 'Greeley Tribune'},
#                'title': 'JBS employees walk off the job over pay dispute - '
#                         'Greeley Tribune',
#                'url': 'https://www.greeleytribune.com/jbs-employees-walk-off-the-job-over-pay-dispute',
#                'urlToImage': 'https://www.greeleytribune.com/wp-content/uploads/2020/06/GRE-L-UFCW-17.jpg?w=1024&h=683'},
#               {'author': 'Stone Fox Capital',
#                'content': 'After the Fed stress test results were released, '
#                           'Wells Fargo (WFC) has fallen close to the pandemic '
#                           'lows due to how the Fed implemented dividend payout '
#                           "restrictions. The stock didn't fall due to the … "
#                           '[+5544 chars]',
#                'description': 'Wells Fargo passed the Fed stress test easily. '
#                               'The Fed placed restrictions on dividend payouts '
#                               'expected to hit Wells Fargo regardless of '
#                               'strong capital levels.',
#                'publishedAt': '2020-07-10T22:58:00Z',
#                'source': {'id': None, 'name': 'Seeking Alpha'},
#                'title': 'Wells Fargo: Fed Overreacts On Dividend Cut - Seeking '
#                         'Alpha',
#                'url': 'https://seekingalpha.com/article/4357892-wells-fargo-fed-overreacts-on-dividend-cut',
#                'urlToImage': 'https://static2.seekingalpha.com/uploads/2020/7/9/234751-15943119626051888.png'},
#               {'author': 'Allison Morrow, CNN Business',
#                'content': None,
#                'description': 'Tesla CEO Elon Musk just zoomed soared past '
#                               'Warren Buffett on the Bloomberg Billionaires '
#                               "Index to become the world's seventh wealthiest "
#                               'person.',
#                'publishedAt': '2020-07-10T22:49:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Elon Musk just became richer than Warren Buffett - '
#                         'CNN',
#                'url': 'https://www.cnn.com/2020/07/10/business/elon-musk-warren-buffett-billionaires/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200630124622-07-elon-musk-0309-restricted-super-tease.jpg'},
#               {'author': 'Wes Goldberg',
#                'content': 'Santa Clara County will open new coronavirus '
#                           'testing sites in San Jose and Gilroy next week.\r\n'
#                           'With two locations in San Jose and one in Gilroy, '
#                           'the sites will provide free COVID-19 nasal swab '
#                           'tests, … [+1460 chars]',
#                'description': 'The sites will provide free COVID-19 nasal swab '
#                               'tests, available without an appointment, '
#                               'symptoms, insurance, or a doctor’s note, and '
#                               'regardless of immigration status.',
#                'publishedAt': '2020-07-10T22:39:00Z',
#                'source': {'id': None, 'name': 'The Mercury News'},
#                'title': 'Santa Clara County opening new free coronavirus test '
#                         'sites - The Mercury News',
#                'url': 'https://www.mercurynews.com/santa-clara-county-opening-new-coronavirus-test-sites',
#                'urlToImage': 'https://www.mercurynews.com/wp-content/uploads/2020/03/TEASER_coronavirus_SANTA_CLARA.jpg?w=1024&h=688'},
#               {'author': 'Marilyn Moritz',
#                'content': 'SAN ANTONIO At a time when people are stocking up '
#                           'on hand sanitizer to combat the coronavirus, the '
#                           'FDA announced two brands are being recalled. They '
#                           'may contain methanol, which can be toxic if ingest… '
#                           '[+2554 chars]',
#                'description': 'Two companies recalled hand sanitizer products '
#                               'because they may contain methanol, which can be '
#                               "toxic if it's ingested or absorbed through the "
#                               'skin.',
#                'publishedAt': '2020-07-10T22:26:00Z',
#                'source': {'id': None, 'name': 'KSAT San Antonio'},
#                'title': 'Two hand sanitizer brands recalled over methanol '
#                         'concerns - KSAT San Antonio',
#                'url': 'https://www.ksat.com/news/local/2020/07/10/two-hand-sanitizer-brands-recalled-over-methanol-concerns/',
#                'urlToImage': 'https://www.ksat.com/resizer/4_9QNg1agIyhVEHD2HgWb8SbBxo=/1600x900/smart/filters:format(jpeg):strip_exif(true):strip_icc(true):no_upscale(true):quality(65)/d1vhqlrjc8h82r.cloudfront.net/07-10-2020/t_02ff707c86a3490aae7fe1c7096606b0_name_image.jpg'},
#               {'author': 'https://www.facebook.com/bbcnews',
#                'content': 'Image caption\r\n'
#                           ' Emirates president Sir Tim Clark\r\n'
#                           'The president of Emirates said the Middle Eastern '
#                           'airline is set to cut as many as 9,000 jobs because '
#                           'of the coronavirus pandemic.\r\n'
#                           'It is the first t… [+2838 chars]',
#                'description': 'The Middle Eastern airline will make more '
#                               "redundancies but says it is 'not as badly off "
#                               "as others'.",
#                'publishedAt': '2020-07-10T21:52:43Z',
#                'source': {'id': None, 'name': 'BBC News'},
#                'title': 'Emirates set to cut 9000 jobs, citing pandemic - BBC '
#                         'News',
#                'url': 'https://www.bbc.com/news/business-53369463',
#                'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16461/production/_113333219_timclarkbbc3.jpg'},
#               {'author': '',
#                'content': 'In 2005, Franklin Leonard was a junior executive at '
#                           "Leonardo DiCaprio's production company. A big part "
#                           'of his job was to find great scripts. The only '
#                           'thing most of the 50,000-some scripts registered … '
#                           '[+762 chars]',
#                'description': 'In 2005, an anonymous list of the best unmade '
#                               'scripts in Hollywood shook up the movie biz. '
#                               'This episode: how a math-loving, movie nerd '
#                               "solved Hollywood's script problem. | Subscribe "
#                               'to our weekly newsletter here.',
#                'publishedAt': '2020-07-10T21:48:53Z',
#                'source': {'id': None, 'name': 'NPR'},
#                'title': 'How Franklin Leonard and The Black List Changed '
#                         'Hollywood : Planet Money - NPR',
#                'url': 'https://www.npr.org/2020/07/10/889708583/hollywoods-black-list',
#                'urlToImage': 'https://media.npr.org/assets/img/2020/07/10/gettyimages-1095125886_wide-9614aab37e83cd7128c07cb580117a6fede331ac.jpg?s=1400'},
#               {'author': 'Megan Henney',
#                'content': 'Companies that contract with major U.S.\xa0cities '
#                           'to provide red light\xa0and other traffic '
#                           'enforcement cameras reaped millions in '
#                           'taxpayer-funded aid through the Paycheck Protection '
#                           'Program despite allege… [+2721 chars]',
#                'description': 'Companies that contract with major U.S.\xa0'
#                               'cities to provide red lights and other traffic '
#                               'enforcement cameras reaped millions in '
#                               'taxpayer-funded aid',
#                'publishedAt': '2020-07-10T21:22:09Z',
#                'source': {'id': None, 'name': 'Fox Business'},
#                'title': 'Millions in PPP aid given to traffic camera companies '
#                         'linked to corruption scandals - Fox Business',
#                'url': 'https://www.foxbusiness.com/economy/foreign-traffic-camera-companies-received-millions-in-ppp-aid',
#                'urlToImage': 'https://a57.foxnews.com/static.foxbusiness.com/foxbusiness.com/content/uploads/2020/07/0/0/red-light-camera-iStock.jpg?ve=1&tl=1'},
#               {'author': 'Alicia Wallace, CNN Business',
#                'content': None,
#                'description': 'Tyson Foods and other meat processors that '
#                               'became early hotspots for the Covid-19 pandemic '
#                               'are reportedly accelerating plans to have '
#                               'robots replace human meatcutters.',
#                'publishedAt': '2020-07-10T21:06:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Tyson and other meat processors are reportedly '
#                         'speeding up plans for robot butchers - CNN',
#                'url': 'https://www.cnn.com/2020/07/10/business/tyson-meatpacking-plants-automation/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200710154815-tyson-foods-plant-0507-super-tease.jpg'},
#               {'author': 'Gene Sloan',
#                'content': 'Get ready for the Great Shrinking of the Fleets in '
#                           'the cruise world.\r\n'
#                           'The CEO of Carnival Corporation — the world’s '
#                           'biggest cruise company — on Friday revealed that '
#                           'its nine brands would remove 13 sh… [+5437 chars]',
#                'description': 'Carnival Corp. is the parent company of '
#                               'Carnival Cruise Line, Princess Cruises, Holland '
#                               'America, Seabourn and five other brands.',
#                'publishedAt': '2020-07-10T21:02:02Z',
#                'source': {'id': None, 'name': 'The Points Guy'},
#                'title': '13 cruise ships to be scrapped or sold as Carnival '
#                         'Corp. manages COVID fallout - The Points Guy',
#                'url': 'http://thepointsguy.com/news/carnival-cruise-ships-sold-scrapped/',
#                'urlToImage': 'https://i2.wp.com/thepointsguy.com/wp-content/uploads/2019/12/Carnival-Panorama_Exterior-3.jpg?fit=1600%2C1067px&ssl=1'},
#               {'author': 'Alex Harring',
#                'content': 'Even when the Great Recession dampened consumer '
#                           "confidence and drove up unemployment things weren't "
#                           'as bad for retailers as they have been during the '
#                           'current Covid-19 crisis, according to a new analy… '
#                           '[+2296 chars]',
#                'description': "The retail sector's first-quarter operating "
#                               'income fell 57.7% compared to last year, '
#                               'marking the worst quarter on record.',
#                'publishedAt': '2020-07-10T20:16:00Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': 'Pandemic deals mightier blow to retail than Great '
#                         'Recession: First-quarter operating income down 58% - '
#                         'CNBC',
#                'url': 'https://www.cnbc.com/2020/07/10/first-quarter-retail-industry-operating-income-falls-58percent.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106611359-1594406147054gettyimages-1221054293.jpeg?v=1594406204'},
#               {'author': 'FreightWaves',
#                'content': '<ul><li>Electric truck and SUV maker Rivian has '
#                           'secured $2.5 billion in new '
#                           'financing</li></ul><ul><li>Analysts:"The days of '
#                           "Tesla's virtually unchallenged dominance may be "
#                           'numbered."</li></ul><ul><l… [+3099 chars]',
#                'description': 'Electric truck and SUV maker Rivian has secured '
#                               '$2.5 billion in new financing Analysts: "The '
#                               "days of Tesla's virtually unchallenged "
#                               'dominance may be ...',
#                'publishedAt': '2020-07-10T20:08:39Z',
#                'source': {'id': None, 'name': 'Benzinga'},
#                'title': 'Electric Truck Maker Rivian Secures $2.5B In New '
#                         'Financing - Benzinga',
#                'url': 'https://www.benzinga.com/news/20/07/16591507/electric-truck-maker-rivian-secures-2-5b-in-new-financing',
#                'urlToImage': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/amazon_orders_100000_1_0.jpg'},
#               {'author': 'Lizzy Gurdus',
#                'content': 'Disney is facing a double-edged sword.\r\n'
#                           'Shares of the entertainment giant climbed Friday as '
#                           'the company prepared to reopen parts of its Disney '
#                           'World theme park in Florida.\r\n'
#                           'Public concern has grown a… [+2547 chars]',
#                'description': 'Disney remains a strong buy-and-hold investment '
#                               'as the company reopens parts of its Florida '
#                               'theme park despite spiking Covid-19 cases in '
#                               'the state, two traders say.',
#                'publishedAt': '2020-07-10T19:53:00Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': 'Disney is still a buy, traders say, as Florida theme '
#                         'parks reopen amid rising coronavirus cases - CNBC',
#                'url': 'https://www.cnbc.com/2020/07/10/disney-world-coronavirus-stock-a-buy-despite-reopening-traders-say.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106611115-1594396714891gettyimages-1225946432.jpeg?v=1594396863'},
#               {'author': 'Chris Isidore, CNN Business',
#                'content': None,
#                'description': "Ford CEO Jim Hackett rejected employees' calls "
#                               'to get out of the police car business, saying '
#                               'the automaker can support the Black Lives '
#                               'Matter movement while selling the majority of '
#                               "America's police cars.",
#                'publishedAt': '2020-07-10T19:51:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Ford pressured to stop selling police cars, but it '
#                         "won't get out of the business - CNN",
#                'url': 'https://www.cnn.com/2020/07/10/business/ford-police-car-sales-black-lives-matter-trnd/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200709111939-ford-nypd-police-car-file-restricted-super-tease.jpg'},
#               {'author': 'Fred Imbert',
#                'content': 'Investors and traders have historically turned to '
#                           'less-risky assets such as U.S. Treasurys to weather '
#                           'market volatility and uncertainty. During the '
#                           'coronavirus pandemic, however, they have turned to '
#                           '… [+5165 chars]',
#                'description': 'Wall Street flocked into these names because '
#                               'they believe their business models can not only '
#                               'weather this downturn, but thrive in it.',
#                'publishedAt': '2020-07-10T19:22:00Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': "Big Tech went from growth stocks to Wall Street's "
#                         'Treasury bond substitute during the coronavirus - '
#                         'CNBC',
#                'url': 'https://www.cnbc.com/2020/07/10/big-tech-went-from-growth-stocks-to-wall-streets-treasury-bond-substitute-during-the-coronavirus.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/105940457-1559231679482img_5394.jpg?v=1594396853'},
#               {'author': 'Sinclair Broadcast Group',
#                'content': 'Ice cream is the comfort food of summer - and the '
#                           'best ice cream is true work of art. And while it '
#                           'might take a little while longer before life gets '
#                           'back to normal, at least we have some of the best … '
#                           '[+3938 chars]',
#                'description': 'Ice cream is the comfort food of summer - and '
#                               'the best ice cream is true work of art. And '
#                               'while it might take a little while longer '
#                               'before life gets back to normal, at least we '
#                               'have some of the best frozen treats to help us '
#                               'all get through it. Below are a few…',
#                'publishedAt': '2020-07-10T19:18:45Z',
#                'source': {'id': None, 'name': 'seattlerefined.com'},
#                'title': 'The best ice cream in Seattle (and how to get it) - '
#                         'seattlerefined.com',
#                'url': 'http://seattlerefined.com/eat-drink/the-best-ice-cream-in-seattle-and-how-to-get-it',
#                'urlToImage': 'http://static-25.sinclairstoryline.com/resources/media/9ffff154-58f7-4b83-8fd6-bc2279f54edc-large16x9_a8ff8fc9a83a4fb9af492736d8302bc3MollyMoonsSpring_SB_14.jpg?1594408322035'},
#               {'author': 'Renee Morad',
#                'content': 'null\r\n'
#                           'Getty\r\n'
#                           'Many unemployed and cash-strapped college students '
#                           'are worried about how theyll survive financially '
#                           'during the upcoming fall semester. Stimulus checks '
#                           'sent through the CARES Act excluded… [+4951 chars]',
#                'description': 'Students are receiving a core benefit of $190 a '
#                               'week, on average, depending on their state, '
#                               'along with an extra $600 per week in '
#                               'unemployment assistance.',
#                'publishedAt': '2020-07-10T19:03:00Z',
#                'source': {'id': None, 'name': 'Forbes'},
#                'title': 'How College Students Can Get Nearly $800 A Week In '
#                         'Pandemic Unemployment Assistance, Backdated From '
#                         'April 2020 Through July 2020 - Forbes',
#                'url': 'https://www.forbes.com/sites/reneemorad/2020/07/10/how-college-students-can-get-nearly-800-a-week-in-pandemic-unemployment-assistance-backdated-from-april-2020-through-july-2020/',
#                'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F200389288-002%2F0x0.jpg'},
#               {'author': 'Josh Owens',
#                'content': None,
#                'description': 'Oil prices fell on Thursday as COVID-19 cases '
#                               'continued to spike in the U.S., which the IEA  '
#                               'highlighted as a major threat to oil markets in '
#                               "today's report, but prices were quick to return "
#                               'to the $40 mark on Friday.',
#                'publishedAt': '2020-07-10T19:00:00Z',
#                'source': {'id': None, 'name': 'OilPrice.com'},
#                'title': 'Oil Returns To $40 After COVID Correction - '
#                         'OilPrice.com',
#                'url': 'https://oilprice.com/Energy/Energy-General/Oil-Returns-To-40-After-COVID-Correction.html',
#                'urlToImage': 'https://d32r1sh890xpii.cloudfront.net/article/718x300/2020-07-10_fn2anixrb0.jpg'},
#               {'author': 'WKRC',
#                'content': None,
#                'description': 'CINCINNATI (WKRC) - Kroger said that for the '
#                               'time being customers will not receive coin '
#                               'change from cash transactions. That change will '
#                               "be applied to customers' loyalty cards.. which "
#                               'will then automatically get used on their next '
#                               'purchase. Customers can also …',
#                'publishedAt': '2020-07-10T18:57:00Z',
#                'source': {'id': None, 'name': 'WKRC TV Cincinnati'},
#                'title': "Kroger won't give coins for change during shortage - "
#                         'WKRC TV Cincinnati',
#                'url': 'http://local12.com/news/local/kroger-wont-give-coins-for-change-during-shortage',
#                'urlToImage': 'http://static-37.sinclairstoryline.com/resources/media/fc7fd927-d678-4e8a-ab70-886a3bc08004-large16x9_gmckrogerbg.PNG?1594407354598'},
#               {'author': 'Matt Wirz, Tom McGinty',
#                'content': 'The Federal Reserve bought about $1.3 billion face '
#                           'value of corporate bonds from June 17-26, boosting '
#                           'its purchases under a market stabilization buying '
#                           'program to about $1.5 billion at the time, acco… '
#                           '[+332 chars]',
#                'description': 'ETF trades made $168 million paper gains; bond '
#                               'purchases include Apollo, Ares and Owl Rock',
#                'publishedAt': '2020-07-10T18:45:00Z',
#                'source': {'id': 'the-wall-street-journal',
#                           'name': 'The Wall Street Journal'},
#                'title': 'Fed Discloses More Corporate Bond and ETF Purchases - '
#                         'The Wall Street Journal',
#                'url': 'https://www.wsj.com/articles/fed-bought-about-1-3-billion-corporate-bonds-in-late-june-11594396039',
#                'urlToImage': 'https://images.wsj.net/im-208043/social'},
#               {'author': 'Jaimy Lee',
#                'content': 'Shares of Gilead Sciences Inc. gained 2.0% on '
#                           'Friday after the drugmaker shared potentially '
#                           'promising data about remdesivir that indicates the '
#                           'experimental COVID-19 drug may reduce deaths, '
#                           'though it … [+3859 chars]',
#                'description': 'The drugmaker is making ‘a confusing '
#                               'suggestion’ that remdesivir can demonstrate a '
#                               'survival benefit, according to a Raymond James '
#                               'analyst',
#                'publishedAt': '2020-07-10T18:40:00Z',
#                'source': {'id': None, 'name': 'MarketWatch'},
#                'title': 'Gilead says coronavirus drug remdesivir can reduce '
#                         'risk of death, but analysts need more proof - '
#                         'MarketWatch',
#                'url': 'https://www.marketwatch.com/story/gilead-says-coronavirus-drug-remdesivir-can-reduce-risk-of-death-but-analysts-need-more-proof-2020-07-10',
#                'urlToImage': 'https://s.marketwatch.com/public/resources/images/MW-IF630_remdes_ZG_20200501085223.jpg'},
#               {'author': 'Brian Orelli, PhD',
#                'content': 'BioNTech (NASDAQ:BNTX) and Pfizer(NYSE:PFE) are '
#                           'right on the heels of Moderna(NASDAQ:MRNA) in the '
#                           'race to potentially develop a messenger RNA (mRNA) '
#                           'vaccine against SARS-CoV-2, the novel coronavirus … '
#                           '[+1670 chars]',
#                'description': "The companies' CEOs give different timelines on "
#                               'a potential submission.',
#                'publishedAt': '2020-07-10T18:34:00Z',
#                'source': {'id': None, 'name': 'Motley Fool'},
#                'title': "Pfizer and BioNTech's Coronavirus Vaccine Ready for "
#                         'Regulatory Submission in December, Maybe Earlier - '
#                         'The Motley Fool',
#                'url': 'https://www.fool.com/investing/2020/07/10/pfizer-and-biontechs-coronavirus-vaccine-ready-for.aspx',
#                'urlToImage': 'https://g.foolcdn.com/editorial/images/581954/vaccination-syringe.jpg'},
#               {'author': 'Adi Robertson',
#                'content': 'Were unwanted Facebook text messages illegal?\r\n'
#                           'Photo by Amelia Holowaty Krales\r\n'
#                           'The Supreme Court has agreed to hear Facebooks '
#                           'defense after an appeals court determined it '
#                           'violated anti-robocalling r… [+1764 chars]',
#                'description': 'The Supreme Court will hear Facebook v. Duguid, '
#                               'a lawsuit alleging that Facebook’s automated '
#                               'text alerts constituted illegal robocalling.',
#                'publishedAt': '2020-07-10T18:25:41Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Supreme Court will hear Facebook robocalling case - '
#                         'The Verge',
#                'url': 'https://www.theverge.com/2020/7/10/21320184/supreme-court-facebook-duguid-robocall-tcpa-class-action-lawsuit',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/dW3PvuXiW3LCt_cPFrJ-wEmn55A=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/15948810/akrales_180614_1777_0110.jpg'},
#               {'author': 'Alex Wilhelm',
#                'content': 'After going private in 2016 after accepting a $32 '
#                           'per share, or $4.3 billion, price from Apollo '
#                           'Global Management, Rackspace is looking once again '
#                           'to the public markets. First going public in 2008, '
#                           'R… [+4394 chars]',
#                'description': 'After going private in 2016 after accepting a '
#                               '$32 per share, or $4.3 billion, price from '
#                               'Apollo Global Management, Rackspace is looking '
#                               'once again to the public markets. First going '
#                               'public in 2008, Rackspace is taking second aim '
#                               'at a public offering around 12…',
#                'publishedAt': '2020-07-10T18:22:14Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'Rackspace preps IPO after going private in 2016 for '
#                         '$4.3B - TechCrunch',
#                'url': 'http://techcrunch.com/2020/07/10/rackspace-preps-ipo-after-going-private-in-2016-for-4-3b/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2015/08/rackspace-earnings.png?w=711'},
#               {'author': "Brian O'Connell",
#                'content': 'While rewards credit cards continue to grow in '
#                           'popularity, U.S. financial consumers don’t always '
#                           'understand how their cards work and what rewards '
#                           'they actually earn.\r\n'
#                           'According to a 2019 study from J… [+3563 chars]',
#                'description': 'Rewards credit cards keep on giving – as long '
#                               'as you keep spending.',
#                'publishedAt': '2020-07-10T18:10:00Z',
#                'source': {'id': None, 'name': 'Fox Business'},
#                'title': 'How do rewards credit cards work? - Fox Business',
#                'url': 'https://www.foxbusiness.com/money/rewards-credit-cards',
#                'urlToImage': 'https://a57.foxnews.com/static.foxbusiness.com/foxbusiness.com/content/uploads/2020/07/0/0/rewards-cc-watermarked.jpg?ve=1&tl=1'},
#               {'author': 'Crystal Kim',
#                'content': '(Bloomberg) -- The allure of electric vehicles is '
#                           'boosting shares of blank-check companies, the '
#                           'latest being Apollo Global Management-backed '
#                           'Spartan Energy Acquisition Corp.\r\n'
#                           'Spartan Energy became so… [+2136 chars]',
#                'description': '(Bloomberg) -- The allure of electric vehicles '
#                               'is boosting shares of blank-check companies, '
#                               'the latest being Apollo Global '
#                               'Management-backed Spartan Energy Acquisition '
#                               'Corp.Spartan Energy became something of an '
#                               'overnight sensation Thursday after Reuters '
#                               'repor…',
#                'publishedAt': '2020-07-10T17:47:00Z',
#                'source': {'id': None, 'name': 'Yahoo Entertainment'},
#                'title': 'Apollo-Backed Blank-Check Company Surges 71% on '
#                         'Possible Fisker Deal - Yahoo Finance',
#                'url': 'https://finance.yahoo.com/news/apollo-backed-blank-check-company-145535304.html',
#                'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/UkeGR986k_MqSmpAhC6phw--~B/aD0xMzMzO3c9MjAwMDtzbT0xO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/27fb7372be626047b5131addb1231c98'},
#               {'author': 'Associated Press',
#                'content': 'SEATTLE (AP) A homeless shelter built on Amazons '
#                           'perfectly manicured urban Seattle campus is a major '
#                           'civic contribution that pushes the company to face '
#                           'the crisis and criticism in the hometown it has… '
#                           '[+420 chars]',
#                'description': 'SEATTLE (AP) — A homeless shelter built on '
#                               'Amazon’s perfectly manicured urban Seattle '
#                               'campus is a major civic contribution that '
#                               'pushes the company to face the crisis and '
#                               'criticism in the hometown it has rapidly '
#                               'transformed. Believed to be the first homeless '
#                               's…',
#                'publishedAt': '2020-07-10T17:43:29Z',
#                'source': {'id': None, 'name': 'KTIV'},
#                'title': "Amazon's homeless shelter faces Seattle crisis, "
#                         'criticism - KTIV',
#                'url': 'https://ktiv.com/2020/07/10/amazons-homeless-shelter-faces-seattle-crisis-criticism/',
#                'urlToImage': 'https://s3-ca-central-1.amazonaws.com/quincy-network/wp-content/uploads/sites/4/2018/08/21141516/AP.jpg'},
#               {'author': 'Jason Diamond',
#                'content': 'Were 30 years and a day away from Forbes publishing '
#                           'the article, An Escalator? In Brooks Brothers?, '
#                           'that tried to make sense of the iconic brands new '
#                           'ownerships handling of the company it had recentl… '
#                           '[+4847 chars]',
#                'description': 'When and how did it all go so wrong for the '
#                               'brand that essentially created the prep '
#                               'aesthetic?',
#                'publishedAt': '2020-07-10T17:09:51Z',
#                'source': {'id': None, 'name': 'InsideHook'},
#                'title': 'The Long, Slow Death of Brooks Brothers, An American '
#                         'Icon - InsideHook',
#                'url': 'https://www.insidehook.com/article/menswear/long-slow-death-brooks-brothers',
#                'urlToImage': 'https://www.insidehook.com/wp-content/uploads/2020/07/GettyImages-1225701734.jpg?resize=1200,800'},
#               {'author': "Investor's Business Daily",
#                'content': 'The Dow Jones Industrial Average was up 200 points '
#                           'Friday afternoon, as the stock market got a boost '
#                           'from bullish coronavirus vaccine news.\r\n'
#                           'XThe Dow Jones industrials rose 0.8% and the '
#                           'S&amp;P 500 a… [+4998 chars]',
#                'description': 'The Dow Jones Industrial Average was up 200 '
#                               'points Friday afternoon as the stock market got '
#                               'a boost from bullish coronavirus vaccine news.',
#                'publishedAt': '2020-07-10T16:55:00Z',
#                'source': {'id': None, 'name': "Investor's Business Daily"},
#                'title': 'Dow Jones Leads Market On Coronavirus Vaccine Hopes, '
#                         "But Nasdaq Slips Into Red - Investor's Business Daily",
#                'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-rallies-lead-stock-market-coronavirus-vaccine-near/',
#                'urlToImage': 'https://www.investors.com/wp-content/uploads/2018/01/stock-bull-18-adobe.jpg'},
#               {'author': None,
#                'content': None,
#                'description': None,
#                'publishedAt': '2020-07-10T16:37:58Z',
#                'source': {'id': 'google-news', 'name': 'Google News'},
#                'title': 'Kids Shipped in Armoires? The Person Who Started the '
#                         'Wayfair Conspiracy Speaks - Newsweek',
#                'url': 'https://news.google.com/__?oc=5',
#                'urlToImage': None},
#               {'author': 'WBNG',
#                'content': '12:33 P.M. UPDATE:\r\n'
#                           '(WBNG) -- The Oakdale Mall says it will reopen on '
#                           'July 20.\r\n'
#                           'The malls says it plans to be compliant with the '
#                           'HVAC filtration mandates by Governor Andrew '
#                           'Cuomo.\r\n'
#                           'Mall Re-opening up… [+861 chars]',
#                'description': '12:33 P.M. UPDATE: (WBNG) -- The Oakdale Mall '
#                               'says it will reopen on July 20. The malls says '
#                               'it plans to be compliant with the HVAC '
#                               'filtration mandates by Governor Andrew Cuomo. '
#                               '📢Mall Re-opening update!Mark your calendar '
#                               '🗓Tentative date July 20th we plan to…',
#                'publishedAt': '2020-07-10T16:30:00Z',
#                'source': {'id': None, 'name': 'WBNG-TV'},
#                'title': 'Oakdale Mall to open July 20 - WBNG-TV',
#                'url': 'http://wbng.com/2020/07/10/malls-open-across-state-but-oakdale-mall-remains-closed/',
#                'urlToImage': 'https://quincy-network.s3.ca-central-1.amazonaws.com/wp-content/uploads/sites/19/2020/07/Oakdale-Mall-Pic.jpg'},
#               {'author': 'Allison Robicelli',
#                'content': 'Kitchenware retailer Sur La Table has filed for '
#                           'Chapter 11 bankruptcy protection in this cuckoo '
#                           'crazy coronavirus world. I must remind you that '
#                           'filing for Chapter 11 bankruptcy does not mean a '
#                           'compan… [+1589 chars]',
#                'description': 'Kitchenware retailer Sur La Table has filed for '
#                               'Chapter 11 bankruptcy protection in this cuckoo '
#                               'crazy coronavirus world. I must remind you that '
#                               'filing for Chapter 11 bankruptcy does not mean '
#                               'a company is going out of business—it means '
#                               'it’s working on reorgani…',
#                'publishedAt': '2020-07-10T16:28:00Z',
#                'source': {'id': None, 'name': 'The Takeout'},
#                'title': 'Sur La Table bankruptcy means big liquidation sales - '
#                         'The Takeout',
#                'url': 'https://thetakeout.com/sur-la-table-bankruptcy-means-big-liquidation-sales-1844337060',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/mascqsvn1a44vvdsfjt0.jpg'},
#               {'author': 'Tanisha Pina',
#                'content': 'Fitness and athleisure brand Lululemon is known for '
#                           'many things: super comfortable yoga and running '
#                           'leggings; stylish everyday clothing thats as '
#                           'comfortable as athletic wear; and high price tags '
#                           'that… [+8831 chars]',
#                'description': 'Lululemon sales are few and far between, but '
#                               "this weekend you can shop the brand's most "
#                               'popular products at steep discounts.',
#                'publishedAt': '2020-07-10T16:15:00Z',
#                'source': {'id': None, 'name': 'Forbes'},
#                'title': 'The Lululemon Online Warehouse Sale You Don’t Want To '
#                         'Miss - Forbes',
#                'url': 'https://www.forbes.com/sites/forbes-personal-shopper/2020/07/10/lululemon-warehouse-sale-what-to-buy/',
#                'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f07847f3e0bd30006e3a375%2F0x0.jpg%3FcropX1%3D43%26cropX2%3D1156%26cropY1%3D0%26cropY2%3D627'},
#               {'author': 'Phil LeBeau',
#                'content': 'American Airlines executives have told Boeing they '
#                           'will not take delivery of 17 737 Max airplanes '
#                           'unless the carrier can secure financing to pay for '
#                           'the aircraft, people familiar with the discussions… '
#                           '[+2440 chars]',
#                'description': 'American Airlines executives have told Boeing '
#                               'they will not take delivery of 17 Boeing 737 '
#                               'Max airplanes unless the airline can secure '
#                               'financing to pay for the aircraft, people '
#                               'familiar with the discussions told CNBC.',
#                'publishedAt': '2020-07-10T16:08:00Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': 'American Airlines tells Boeing: No financing, no 737 '
#                         'Max deliveries - CNBC',
#                'url': 'https://www.cnbc.com/2020/07/10/american-airlines-tells-boeing-no-financing-no-737-max-deliveries.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106011692-1562770624382aa.jpg?v=1594395792'},
#               {'author': 'Jonathan Stempel',
#                'content': '(Reuters) - Berkshire Hathaway Inc has reduced its '
#                           'share count by 1.2% since April 23, a regulatory '
#                           'filing shows, suggesting that Chairman Warren '
#                           'Buffett might have become more aggressive in '
#                           'repurcha… [+2750 chars]',
#                'description': 'Berkshire Hathaway Inc has reduced its share '
#                               'count by 1.2% since April 23, a regulatory '
#                               'filing shows, suggesting that Chairman Warren '
#                               'Buffett might have become more aggressive in '
#                               'repurchasing its significantly underperforming '
#                               'stock.',
#                'publishedAt': '2020-07-10T16:08:00Z',
# ...
#                'urlToImage': None},
#               {'author': 'Tom Warren',
#                'content': 'The pandemic has created a demand for PCs and '
#                           'laptops\r\n'
#                           'Photo by Amelia Holowaty Krales / The Verge\r\n'
#                           'The ongoing coronavirus pandemic has made it more '
#                           'difficult to buy a new laptop recently, and were … '
#                           '[+2081 chars]',
#                'description': 'Demand for PCs and laptops has increased during '
#                               'the coronavirus pandemic. Both IDC and Gartner '
#                               'report that PC shipments have increased, just '
#                               'as businesses and schools adjust to remote work '
#                               'and education.',
#                'publishedAt': '2020-07-10T10:11:55Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'PC shipments surge as the world gets serious about '
#                         'working from home - The Verge',
#                'url': 'https://www.theverge.com/2020/7/10/21319750/pc-shipments-coronavirus-pandemic-idc-gartner-q2-2020',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/OQ3ACTa5rJKg5LwREaxoEdqzx-4=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/19250342/akrales_190930_3689_0056.jpg'},
#               {'author': 'Derek Brower',
#                'content': 'Expert insights, analysis and smart data help you '
#                           'cut through the noise to spot trends,\r\n'
#                           'risks and opportunities.\r\n'
#                           'Join over 300,000 Finance professionals who already '
#                           'subscribe to the FT.',
#                'description': 'News, analysis and comment from the Financial '
#                               'Times, the worldʼs leading global business '
#                               'publication',
#                'publishedAt': '2020-07-10T09:53:00Z',
#                'source': {'id': 'financial-times', 'name': 'Financial Times'},
#                'title': 'Is the party finally over for US oil and gas? - '
#                         'Financial Times',
#                'url': 'https://www.ft.com/content/e9e0ce5d-3bc0-45dd-9b7c-54b0828b9e99',
#                'urlToImage': None},
#               {'author': 'Suzanne Phan, KOMO News Reporter',
#                'content': None,
#                'description': 'The race to develop a COVID-19 vaccine is '
#                               'heating up globally and right here in our area. '
#                               'In Seattle, we&rsquo;ve got a lot of companies '
#                               'and volunteers doing their part to try and '
#                               'help. &ldquo;It&rsquo;s been 16 weeks since I '
#                               'had the first dose," said Jennife…',
#                'publishedAt': '2020-07-10T06:35:30Z',
#                'source': {'id': None, 'name': 'KOMO News'},
#                'title': 'First Seattle volunteer in human COVID-19 vaccine '
#                         "trials says she feels 'fantastic' - KOMO News",
#                'url': 'http://komonews.com/news/coronavirus/first-seattle-volunteer-in-human-covid-19-vaccine-trials-says-she-feels-fantastic',
#                'urlToImage': 'http://static-31.sinclairstoryline.com/resources/media/1ef38c1d-5bc2-404b-b0b9-a09a93c58022-large16x9_FTP9645PKgCovid19VaccTrialsSuzanne_frame_349.jpg?1594362750137'},
#               {'author': 'Stan Choe, Damian J. Troise',
#                'content': 'NEW YORK (AP) Optimism returned to Wall Street on '
#                           'Friday, and stocks rallied to cap a shaky week '
#                           'dogged by worries that rising coronavirus counts '
#                           'may halt the economys recent upswing. \r\n'
#                           'The S&amp;P 5… [+4096 chars]',
#                'description': 'NEW YORK (AP) — Optimism returned to Wall '
#                               'Street on Friday, and stocks rallied to cap a '
#                               'shaky week dogged by worries that rising '
#                               'coronavirus counts may halt the economy’s '
#                               'recent upswing....',
#                'publishedAt': '2020-07-10T05:58:32Z',
#                'source': {'id': 'associated-press', 'name': 'Associated Press'},
#                'title': 'Wall Street rallies as optimism returns to cap '
#                         'erratic week - The Associated Press',
#                'url': 'https://apnews.com/e3fe25aabbfc1fee055b0e14e7708cfa',
#                'urlToImage': 'https://storage.googleapis.com/afs-prod/media/55812eb94ee0423980cf5daa19fd3f47/3000.jpeg'},
#               {'author': 'Herb Scribner',
#                'content': 'The Environmental Protection Agency has approved '
#                           'the first disinfectant to kill the coronavirus, and '
#                           'its fairly common Lysol.\r\n'
#                           'Whats happening\r\n'
#                           '<ul><li>The EPA tested two versions of Lysol '
#                           'spray.</li… [+1102 chars]',
#                'description': 'EPA reveals a slew of cleaning products to use '
#                               'to kill COVID-19',
#                'publishedAt': '2020-07-10T02:00:00Z',
#                'source': {'id': None, 'name': 'Deseret News'},
#                'title': 'Coronavirus: Lysol, Clorox, Microban 24 kills '
#                         'COVID-19, EPA says - Deseret News',
#                'url': 'https://www.deseret.com/u-s-world/2020/7/9/21318587/coronavirus-lysol-clorox-microban-24-kill-covid-19',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/Bx1cP5vedjfDZ_6M-fh4k2tu_pU=/0x317:4204x2518/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/20074950/AP20112086475479.jpg'},
#               {'author': 'Megan Cerullo',
#                'content': 'Coffee giant Starbucks will soon enforce a mask '
#                           'mandate across all of its U.S. stores beginning '
#                           'July 15, requiring every customer who enters a '
#                           'company-owned store in the U.S. to wear a face '
#                           'coverings… [+1100 chars]',
#                'description': 'In the absence of a national mandate, Starbucks '
#                               'will require that everyone mask up or else have '
#                               'their coffee delivered.',
#                'publishedAt': '2020-07-09T20:59:00Z',
#                'source': {'id': 'cbs-news', 'name': 'CBS News'},
#                'title': 'Starbucks requiring all U.S. customers to wear masks '
#                         'starting July 15 - CBS News',
#                'url': 'https://www.cbsnews.com/news/starbucks-face-masks-required-customers-july-15/',
#                'urlToImage': 'https://cbsnews3.cbsistatic.com/hub/i/r/2020/07/09/36c49f0e-6b97-41bb-a935-94b0c9c916c0/thumbnail/1200x630/635e641a356feff0068ae87dd101163b/gettyimages-1217457825.jpg'},
#               {'author': 'Daveen Rae Kurutz',
#                'content': 'Beaver County officials continue to wait to see if '
#                           'the state Department of Health plan to add indoor '
#                           'dining and gathering restrictions to the region., '
#                           'while Allegheny County health officials extended… '
#                           '[+4087 chars]',
#                'description': 'Beaver County officials continue to wait to see '
#                               'if the state Department of Health plan to add '
#                               'indoor dining and gathering restrictions to the '
#                               'region.,',
#                'publishedAt': '2020-07-09T20:06:00Z',
#                'source': {'id': None, 'name': 'Timesonline.com'},
#                'title': 'No new restrictions in Beaver County as cases rise; '
#                         'Allegheny County changes orders - The Times',
#                'url': 'https://www.timesonline.com/article/20200709/NEWS/200709145',
#                'urlToImage': 'https://www.timesonline.com/storyimage/PA/20200709/NEWS/200709145/AR/0/AR-200709145.jpg'},
#               {'author': 'Parija Kavilanz, CNN Business',
#                'content': None,
#                'description': 'The new work-from-home normal has rapidly '
#                               'recalibrated the fashion code for professional '
#                               'wear. That spells trouble for big retailers who '
#                               'sell clothing normally worn at the office.',
#                'publishedAt': '2020-07-09T20:01:00Z',
#                'source': {'id': 'cnn', 'name': 'CNN'},
#                'title': 'Coronavirus canceled office clothing. These stores '
#                         'are in big trouble - CNN',
#                'url': 'https://www.cnn.com/2020/07/08/business/office-wear-dead-brooks-brothers/index.html',
#                'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200708131951-store-mannequins-suits-nyc-0622-super-tease.jpg'},
#               {'author': 'Kirsten Korosec',
#                'content': 'Harley-Davidson, the storied and struggling '
#                           'Milwaukee-based company that last year launched its '
#                           'first production electric motorcycle in an effort '
#                           'to reboot sales and appeal to a younger customer '
#                           'base… [+3195 chars]',
#                'description': 'Harley-Davidson, the storied and struggling '
#                               'Milwaukee-based company that last year launched '
#                               'its first production electric motorcycle in an '
#                               'effort to reboot sales and appeal to a younger '
#                               'customer base, is cutting 700 jobs from its '
#                               'global operations. About 500 …',
#                'publishedAt': '2020-07-09T19:56:57Z',
#                'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#                'title': 'Harley-Davidson’s ‘Rewire’ plan starts with 700 jobs '
#                         'cuts, ousted CFO - TechCrunch',
#                'url': 'http://techcrunch.com/2020/07/09/harley-davidsons-rewire-plan-starts-with-700-jobs-cuts-ousted-cfo/',
#                'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/07/LiveWire-Charging-Harley-Davidson.jpg?w=533'},
#               {'author': 'Andrew Jacobs',
#                'content': 'The collapse of the antibiotic market has '
#                           'dramatically reduced the number of promising drugs. '
#                           'Between 1980 and 2009, the Food and Drug '
#                           'Administration approved 61 new antibiotics for '
#                           'systemic use; ove… [+1914 chars]',
#                'description': 'New medicines are desperately needed to treat a '
#                               'growing number of drug-resistant infections, '
#                               'but many companies developing the drugs are '
#                               'short on cash and investments.',
#                'publishedAt': '2020-07-09T19:29:00Z',
#                'source': {'id': None, 'name': 'New York Times'},
#                'title': 'Drug Giants Create Fund to Bolster Struggling '
#                         'Antibiotic Start-Ups - The New York Times',
#                'url': 'https://www.nytimes.com/2020/07/09/health/antibiotics-pharma-drug-resistance.html',
#                'urlToImage': 'https://static01.nyt.com/images/2020/07/10/science/09antibiotics-print/merlin_152334294_d66d1aea-43f3-476d-a43e-d1cbe05dcb21-facebookJumbo.jpg'},
#               {'author': 'Brendan Bures, The Fresh Toast',
#                'content': None,
#                'description': 'CBD anti-inflammatory properties and mental '
#                               'health treatment capabilities demand further '
#                               'investigation for coronavirus patients, '
#                               'according to a new study.',
#                'publishedAt': '2020-07-09T18:08:00Z',
#                'source': {'id': None, 'name': 'Chicago Tribune'},
#                'title': 'Researchers say CBD could provide vital treatment for '
#                         'coronavirus - Chicago Tribune',
#                'url': 'https://www.chicagotribune.com/marijuana/sns-tft-cbd-coronavirus-treatment-research-20200709-4gp2a2w76fah7p277n3ss42yby-story.html',
#                'urlToImage': 'https://www.chicagotribune.com/resizer/ZcGqED4PNvgDzGstvM0TcHpx1rc=/1200x0/top/cloudfront-us-east-1.images.arcpublishing.com/tronc/E7SS6PWJKJBYBDZCC52TBN7PRA.jpg'},
#               {'author': 'Kate Dore',
#                'content': 'Are you curious to see if your employer or local '
#                           'businesses got a slice of the governments $2.2 '
#                           'trillion stimulus package? This week, ProPublica, '
#                           'an independent, non-profit newsroom, released a new '
#                           'P… [+1591 chars]',
#                'description': 'Are you curious to see if your employer or '
#                               'local businesses got a slice of the '
#                               'government’s $2.2 trillion stimulus package? '
#                               'This week, ProPublica, an independent, '
#                               'non-profit newsroom, released a new Paycheck '
#                               'Protection Program (PPP) tracking tool.',
#                'publishedAt': '2020-07-09T18:00:00Z',
#                'source': {'id': None, 'name': 'Lifehacker.com'},
#                'title': "Find Out Who Got a PPP Loan with ProPublica's New "
#                         'Tool - Lifehacker',
#                'url': 'https://lifehacker.com/find-out-who-got-a-ppp-loan-with-propublicas-new-tool-1844324044',
#                'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/sqvd7ih0ptuhjgljca66.jpg'},
#               {'author': None,
#                'content': None,
#                'description': None,
#                'publishedAt': '2020-07-09T16:30:00Z',
#                'source': {'id': None, 'name': 'Triangle Business Journal'},
#                'title': 'Exclusive: Denver-based tech company announces '
#                         'employees will work from home permanently - Denver '
#                         'Business Journal',
#                'url': 'https://www.bizjournals.com/denver/news/2020/07/09/visible-permanent-work-from-home-denver.html',
#                'urlToImage': None},
#               {'author': 'Melissa Repko',
#                'content': 'Walgreens Boots Alliance\xa0said Thursday that the '
#                           'pandemic hurt its fiscal third-quarter results as '
#                           'fewer people went to the doctor and got '
#                           'prescriptions and the company spent more to staff '
#                           'and clean s… [+4414 chars]',
#                'description': 'Walgreens Boots Alliance said its profits were '
#                               'squeezed by a shift in sales to low-margin '
#                               'items, increased supply-chain costs and higher '
#                               'expenses for labor and store cleaning.',
#                'publishedAt': '2020-07-09T11:45:00Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': 'Walgreens swings to a quarterly loss as coronavirus '
#                         'drives up costs, lowers doctor visits; shares fall - '
#                         'CNBC',
#                'url': 'https://www.cnbc.com/2020/07/09/walgreens-wba-earnings-q3-2020.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/105585479-1555505076684bootswalgreens.jpg?v=1562601239'}],
#  'status': 'ok',
#  'totalResults': 70}

# %%
# Convert the json response to a dataframe
df = pd.DataFrame.from_dict(response_json)

# %%
print(df)
# Out:
#    status  totalResults                                           articles
# 0      ok            70  {'source': {'id': None, 'name': 'Sunbury Daily...
# 1      ok            70  {'source': {'id': 'cnn', 'name': 'CNN'}, 'auth...
# 2      ok            70  {'source': {'id': 'usa-today', 'name': 'USA To...
# 3      ok            70  {'source': {'id': None, 'name': 'Gizmodo.com'}...
# 4      ok            70  {'source': {'id': None, 'name': 'OregonLive'},...
# ..    ...           ...                                                ...
# 65     ok            70  {'source': {'id': None, 'name': 'New York Time...
# 66     ok            70  {'source': {'id': None, 'name': 'Chicago Tribu...
# 67     ok            70  {'source': {'id': None, 'name': 'Lifehacker.co...
# 68     ok            70  {'source': {'id': None, 'name': 'Triangle Busi...
# 69     ok            70  {'source': {'id': None, 'name': 'CNBC'}, 'auth...
#
# [70 rows x 3 columns]

# %%
df = pd.concat([df.drop(['articles'], axis=1), df['articles'].apply(pd.Series)], axis=1)

# %%
print(df)
# Out:
#    status  totalResults                                             source  \
# 0      ok            70         {'id': None, 'name': 'Sunbury Daily Item'}
# 1      ok            70                       {'id': 'cnn', 'name': 'CNN'}
# 2      ok            70           {'id': 'usa-today', 'name': 'USA Today'}
# 3      ok            70                {'id': None, 'name': 'Gizmodo.com'}
# 4      ok            70                 {'id': None, 'name': 'OregonLive'}
# ..    ...           ...                                                ...
# 65     ok            70             {'id': None, 'name': 'New York Times'}
# 66     ok            70            {'id': None, 'name': 'Chicago Tribune'}
# 67     ok            70             {'id': None, 'name': 'Lifehacker.com'}
# 68     ok            70  {'id': None, 'name': 'Triangle Business Journal'}
# 69     ok            70                       {'id': None, 'name': 'CNBC'}
#
#                                         author  \
# 0   Francis Scarcella fscarcella@dailyitem.com
# 1          Lauren del Valle and Amir Vera, CNN
# 2                                  Josh Rivera
# 3                                   Catie Keck
# 4                 The Oregonian/OregonLive.com
# ..                                         ...
# 65                               Andrew Jacobs
# 66              Brendan Bures, The Fresh Toast
# 67                                   Kate Dore
# 68                                        None
# 69                               Melissa Repko
#
#                                                 title  \
# 0   UPDATE Two people reported dead; no threat to ...
# 1   3 people test positive for Covid-19 after taki...
# 2   Five Guys says employees who refused to serve ...
# 3   I Have Good News and Bad News About NBC's Stre...
# 4   MUJI U.S.A. files for bankruptcy, blames coron...
# ..                                                ...
# 65  Drug Giants Create Fund to Bolster Struggling ...
# 66  Researchers say CBD could provide vital treatm...
# 67  Find Out Who Got a PPP Loan with ProPublica's ...
# 68  Exclusive: Denver-based tech company announces...
# 69  Walgreens swings to a quarterly loss as corona...
#
#                                           description  \
# 0   HUMMELS WHARF — Two people are dead following ...
# 1   The airline says it is following the guidance ...
# 2   A group of Five Guys employees who refused to ...
# 3                      Well, which do you want first?
# 4   The retail outlet has a Portland store, which ...
# ..                                                ...
# 65  New medicines are desperately needed to treat ...
# 66  CBD anti-inflammatory properties and mental he...
# 67  Are you curious to see if your employer or loc...
# 68                                               None
# 69  Walgreens Boots Alliance said its profits were...
#
#                                                   url  \
# 0   https://www.dailyitem.com/news/update-state-po...
# 1   https://www.cnn.com/2020/07/10/us/delta-air-li...
# 2   https://www.usatoday.com/story/money/food/2020...
# 3   https://gizmodo.com/i-have-good-news-and-bad-n...
# 4   https://www.oregonlive.com/business/2020/07/mu...
# ..                                                ...
# 65  https://www.nytimes.com/2020/07/09/health/anti...
# 66  https://www.chicagotribune.com/marijuana/sns-t...
# 67  https://lifehacker.com/find-out-who-got-a-ppp-...
# 68  https://www.bizjournals.com/denver/news/2020/0...
# 69  https://www.cnbc.com/2020/07/09/walgreens-wba-...
#
#                                            urlToImage           publishedAt  \
# 0   https://bloximages.chicago2.vip.townnews.com/d...  2020-07-11T02:00:00Z
# 1   https://cdn.cnn.com/cnnnext/dam/assets/2003201...  2020-07-11T00:25:00Z
# 2   https://www.gannett-cdn.com/-mm-/1e50282dc070f...  2020-07-11T00:13:20Z
# 3   https://i.kinja-img.com/gawker-media/image/upl...  2020-07-11T00:10:00Z
# 4   https://www.oregonlive.com/resizer/pjarGAcVw1t...  2020-07-10T23:20:00Z
# ..                                                ...                   ...
# 65  https://static01.nyt.com/images/2020/07/10/sci...  2020-07-09T19:29:00Z
# 66  https://www.chicagotribune.com/resizer/ZcGqED4...  2020-07-09T18:08:00Z
# 67  https://i.kinja-img.com/gawker-media/image/upl...  2020-07-09T18:00:00Z
# 68                                               None  2020-07-09T16:30:00Z
# 69  https://image.cnbcfm.com/api/v1/image/10558547...  2020-07-09T11:45:00Z
#
#                                               content
# 0   HUMMELS WHARF Two people are dead following a ...
# 1   (CNN)Three people have tested positive for cor...
# 2   A group of Five Guys employees who refused to ...
# 3   Well, which do you want first?\r\nLets start w...
# 4   MUJI U.S.A., a division of the Japanese retail...
# ..                                                ...
# 65  The collapse of the antibiotic market has dram...
# 66                                               None
# 67  Are you curious to see if your employer or loc...
# 68                                               None
# 69  Walgreens Boots Alliance said Thursday that th...
#
# [70 rows x 10 columns]

# %%
df.shape
# Out:
# (70, 10)

# %%
df.head(50)
# Out:
#    status  totalResults                                             source  \
# 0      ok            70         {'id': None, 'name': 'Sunbury Daily Item'}
# 1      ok            70                       {'id': 'cnn', 'name': 'CNN'}
# 2      ok            70           {'id': 'usa-today', 'name': 'USA Today'}
# 3      ok            70                {'id': None, 'name': 'Gizmodo.com'}
# 4      ok            70                 {'id': None, 'name': 'OregonLive'}
# 5      ok            70                       {'id': None, 'name': 'CNET'}
# 6      ok            70            {'id': None, 'name': 'Greeley Tribune'}
# 7      ok            70              {'id': None, 'name': 'Seeking Alpha'}
# 8      ok            70                       {'id': 'cnn', 'name': 'CNN'}
# 9      ok            70           {'id': None, 'name': 'The Mercury News'}
# 10     ok            70           {'id': None, 'name': 'KSAT San Antonio'}
# 11     ok            70                   {'id': None, 'name': 'BBC News'}
# 12     ok            70                        {'id': None, 'name': 'NPR'}
# 13     ok            70               {'id': None, 'name': 'Fox Business'}
# 14     ok            70                       {'id': 'cnn', 'name': 'CNN'}
# 15     ok            70             {'id': None, 'name': 'The Points Guy'}
# 16     ok            70                       {'id': None, 'name': 'CNBC'}
# 17     ok            70                   {'id': None, 'name': 'Benzinga'}
# 18     ok            70                       {'id': None, 'name': 'CNBC'}
# 19     ok            70                       {'id': 'cnn', 'name': 'CNN'}
# 20     ok            70                       {'id': None, 'name': 'CNBC'}
# 21     ok            70         {'id': None, 'name': 'seattlerefined.com'}
# 22     ok            70                     {'id': None, 'name': 'Forbes'}
# 23     ok            70               {'id': None, 'name': 'OilPrice.com'}
# 24     ok            70         {'id': None, 'name': 'WKRC TV Cincinnati'}
# 25     ok            70  {'id': 'the-wall-street-journal', 'name': 'The...
# 26     ok            70                {'id': None, 'name': 'MarketWatch'}
# 27     ok            70                {'id': None, 'name': 'Motley Fool'}
# 28     ok            70           {'id': 'the-verge', 'name': 'The Verge'}
# 29     ok            70         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 30     ok            70               {'id': None, 'name': 'Fox Business'}
# 31     ok            70        {'id': None, 'name': 'Yahoo Entertainment'}
# 32     ok            70                       {'id': None, 'name': 'KTIV'}
# 33     ok            70                 {'id': None, 'name': 'InsideHook'}
# 34     ok            70  {'id': None, 'name': 'Investor's Business Daily'}
# 35     ok            70       {'id': 'google-news', 'name': 'Google News'}
# 36     ok            70                    {'id': None, 'name': 'WBNG-TV'}
# 37     ok            70                {'id': None, 'name': 'The Takeout'}
# 38     ok            70                     {'id': None, 'name': 'Forbes'}
# 39     ok            70                       {'id': None, 'name': 'CNBC'}
# 40     ok            70               {'id': 'reuters', 'name': 'Reuters'}
# 41     ok            70                       {'id': None, 'name': 'CNBC'}
# 42     ok            70                {'id': None, 'name': 'Motley Fool'}
# 43     ok            70       {'id': 'google-news', 'name': 'Google News'}
# 44     ok            70        {'id': None, 'name': 'Yahoo Entertainment'}
# 45     ok            70                       {'id': None, 'name': 'WGME'}
# 46     ok            70             {'id': None, 'name': 'Endpoints News'}
# 47     ok            70               {'id': 'reuters', 'name': 'Reuters'}
# 48     ok            70            {'id': None, 'name': 'WPXI Pittsburgh'}
# 49     ok            70                    {'id': None, 'name': 'WKBW-TV'}
#
#                                         author  \
# 0   Francis Scarcella fscarcella@dailyitem.com
# 1          Lauren del Valle and Amir Vera, CNN
# 2                                  Josh Rivera
# 3                                   Catie Keck
# 4                 The Oregonian/OregonLive.com
# 5                                 Steven Ewing
# 6                                 Cuyler Meade
# 7                            Stone Fox Capital
# 8                 Allison Morrow, CNN Business
# 9                                 Wes Goldberg
# 10                              Marilyn Moritz
# 11            https://www.facebook.com/bbcnews
# 12
# 13                                Megan Henney
# 14                Alicia Wallace, CNN Business
# 15                                  Gene Sloan
# 16                                Alex Harring
# 17                                FreightWaves
# 18                                Lizzy Gurdus
# 19                 Chris Isidore, CNN Business
# 20                                 Fred Imbert
# 21                    Sinclair Broadcast Group
# 22                                 Renee Morad
# 23                                  Josh Owens
# 24                                        WKRC
# 25                      Matt Wirz, Tom McGinty
# 26                                   Jaimy Lee
# 27                           Brian Orelli, PhD
# 28                               Adi Robertson
# 29                                Alex Wilhelm
# 30                             Brian O'Connell
# 31                                 Crystal Kim
# 32                            Associated Press
# 33                               Jason Diamond
# 34                   Investor's Business Daily
# 35                                        None
# 36                                        WBNG
# 37                           Allison Robicelli
# 38                                Tanisha Pina
# 39                                 Phil LeBeau
# 40                            Jonathan Stempel
# 41                                Lizzy Gurdus
# 42                                Lou Whiteman
# 43                                        None
# 44                               David Knowles
# 45                                        WGME
# 46                                  Jason Mast
# 47                              Lucia Mutikani
# 48                         WPXI.com News Staff
# 49                              Megan Erbacher
#
#                                                 title  \
# 0   UPDATE Two people reported dead; no threat to ...
# 1   3 people test positive for Covid-19 after taki...
# 2   Five Guys says employees who refused to serve ...
# 3   I Have Good News and Bad News About NBC's Stre...
# 4   MUJI U.S.A. files for bankruptcy, blames coron...
# 5   2021 Ford Bronco leaks ahead of Monday's debut...
# 6   JBS employees walk off the job over pay disput...
# 7   Wells Fargo: Fed Overreacts On Dividend Cut - ...
# 8   Elon Musk just became richer than Warren Buffe...
# 9   Santa Clara County opening new free coronaviru...
# 10  Two hand sanitizer brands recalled over methan...
# 11  Emirates set to cut 9000 jobs, citing pandemic...
# 12  How Franklin Leonard and The Black List Change...
# 13  Millions in PPP aid given to traffic camera co...
# 14  Tyson and other meat processors are reportedly...
# 15  13 cruise ships to be scrapped or sold as Carn...
# 16  Pandemic deals mightier blow to retail than Gr...
# 17  Electric Truck Maker Rivian Secures $2.5B In N...
# 18  Disney is still a buy, traders say, as Florida...
# 19  Ford pressured to stop selling police cars, bu...
# 20  Big Tech went from growth stocks to Wall Stree...
# 21  The best ice cream in Seattle (and how to get ...
# 22  How College Students Can Get Nearly $800 A Wee...
# 23  Oil Returns To $40 After COVID Correction - Oi...
# 24  Kroger won't give coins for change during shor...
# 25  Fed Discloses More Corporate Bond and ETF Purc...
# 26  Gilead says coronavirus drug remdesivir can re...
# 27  Pfizer and BioNTech's Coronavirus Vaccine Read...
# 28  Supreme Court will hear Facebook robocalling c...
# 29  Rackspace preps IPO after going private in 201...
# 30   How do rewards credit cards work? - Fox Business
# 31  Apollo-Backed Blank-Check Company Surges 71% o...
# 32  Amazon's homeless shelter faces Seattle crisis...
# 33  The Long, Slow Death of Brooks Brothers, An Am...
# 34  Dow Jones Leads Market On Coronavirus Vaccine ...
# 35  Kids Shipped in Armoires? The Person Who Start...
# 36             Oakdale Mall to open July 20 - WBNG-TV
# 37  Sur La Table bankruptcy means big liquidation ...
# 38  The Lululemon Online Warehouse Sale You Don’t ...
# 39  American Airlines tells Boeing: No financing, ...
# 40  Buffett's Berkshire Hathaway reduces share cou...
# 41  Are leveraged and inverse ETFs worth the risk?...
# 42  United Strikes Deal With Pilots on Buyouts, Ea...
# 43  WASDE: Lower Corn Supplies on Due to Acreage R...
# 44  Looking ahead to a COVID vaccine: Who will mak...
# 45  Union threatens to fine BIW workers if they cr...
# 46  Another four biotechs scratch out the first nu...
# 47  U.S. producer prices unexpectedly fall; underl...
# 48  Group sues owners of Kennywood, Sandcastle, Id...
# 49  8,000 National Grid customers without power in...
#
#                                           description  \
# 0   HUMMELS WHARF — Two people are dead following ...
# 1   The airline says it is following the guidance ...
# 2   A group of Five Guys employees who refused to ...
# 3                      Well, which do you want first?
# 4   The retail outlet has a Portland store, which ...
# 5   Here's our best look yet at Ford's new two-doo...
# 6   Employees of all levels reportedly walked off ...
# 7   Wells Fargo passed the Fed stress test easily....
# 8   Tesla CEO Elon Musk just zoomed soared past Wa...
# 9   The sites will provide free COVID-19 nasal swa...
# 10  Two companies recalled hand sanitizer products...
# 11  The Middle Eastern airline will make more redu...
# 12  In 2005, an anonymous list of the best unmade ...
# 13  Companies that contract with major U.S. cities...
# 14  Tyson Foods and other meat processors that bec...
# 15  Carnival Corp. is the parent company of Carniv...
# 16  The retail sector's first-quarter operating in...
# 17  Electric truck and SUV maker Rivian has secure...
# 18  Disney remains a strong buy-and-hold investmen...
# 19  Ford CEO Jim Hackett rejected employees' calls...
# 20  Wall Street flocked into these names because t...
# 21  Ice cream is the comfort food of summer - and ...
# 22  Students are receiving a core benefit of $190 ...
# 23  Oil prices fell on Thursday as COVID-19 cases ...
# 24  CINCINNATI (WKRC) - Kroger said that for the t...
# 25  ETF trades made $168 million paper gains; bond...
# 26  The drugmaker is making ‘a confusing suggestio...
# 27  The companies' CEOs give different timelines o...
# 28  The Supreme Court will hear Facebook v. Duguid...
# 29  After going private in 2016 after accepting a ...
# 30  Rewards credit cards keep on giving – as long ...
# 31  (Bloomberg) -- The allure of electric vehicles...
# 32  SEATTLE (AP) — A homeless shelter built on Ama...
# 33  When and how did it all go so wrong for the br...
# 34  The Dow Jones Industrial Average was up 200 po...
# 35                                               None
# 36  12:33 P.M. UPDATE: (WBNG) -- The Oakdale Mall ...
# 37  Kitchenware retailer Sur La Table has filed fo...
# 38  Lululemon sales are few and far between, but t...
# 39  American Airlines executives have told Boeing ...
# 40  Berkshire Hathaway Inc has reduced its share c...
# 41  Leveraged and inverse exchange-traded funds ca...
# 42  The agreement might not be enough to avoid lay...
# 43                                               None
# 44  With lives and billions of dollars at stake se...
# 45  The Local S6 union released a statement on Fac...
# 46  Four more biotechs are raising their offers in...
# 47  U.S. producer prices unexpectedly fell in June...
# 48  A group of parents of children with disabiliti...
# 49  As Western New York entered another day of a h...
#
#                                                   url  \
# 0   https://www.dailyitem.com/news/update-state-po...
# 1   https://www.cnn.com/2020/07/10/us/delta-air-li...
# 2   https://www.usatoday.com/story/money/food/2020...
# 3   https://gizmodo.com/i-have-good-news-and-bad-n...
# 4   https://www.oregonlive.com/business/2020/07/mu...
# 5   https://www.cnet.com/roadshow/news/2021-ford-b...
# 6   https://www.greeleytribune.com/jbs-employees-w...
# 7   https://seekingalpha.com/article/4357892-wells...
# 8   https://www.cnn.com/2020/07/10/business/elon-m...
# 9   https://www.mercurynews.com/santa-clara-county...
# 10  https://www.ksat.com/news/local/2020/07/10/two...
# 11         https://www.bbc.com/news/business-53369463
# 12  https://www.npr.org/2020/07/10/889708583/holly...
# 13  https://www.foxbusiness.com/economy/foreign-tr...
# 14  https://www.cnn.com/2020/07/10/business/tyson-...
# 15  http://thepointsguy.com/news/carnival-cruise-s...
# 16  https://www.cnbc.com/2020/07/10/first-quarter-...
# 17  https://www.benzinga.com/news/20/07/16591507/e...
# 18  https://www.cnbc.com/2020/07/10/disney-world-c...
# 19  https://www.cnn.com/2020/07/10/business/ford-p...
# 20  https://www.cnbc.com/2020/07/10/big-tech-went-...
# 21  http://seattlerefined.com/eat-drink/the-best-i...
# 22  https://www.forbes.com/sites/reneemorad/2020/0...
# 23  https://oilprice.com/Energy/Energy-General/Oil...
# 24  http://local12.com/news/local/kroger-wont-give...
# 25  https://www.wsj.com/articles/fed-bought-about-...
# 26  https://www.marketwatch.com/story/gilead-says-...
# 27  https://www.fool.com/investing/2020/07/10/pfiz...
# 28  https://www.theverge.com/2020/7/10/21320184/su...
# 29  http://techcrunch.com/2020/07/10/rackspace-pre...
# 30  https://www.foxbusiness.com/money/rewards-cred...
# 31  https://finance.yahoo.com/news/apollo-backed-b...
# 32  https://ktiv.com/2020/07/10/amazons-homeless-s...
# 33  https://www.insidehook.com/article/menswear/lo...
# 34  https://www.investors.com/market-trend/stock-m...
# 35  https://news.google.com/__i/rss/rd/articles/CB...
# 36  http://wbng.com/2020/07/10/malls-open-across-s...
# 37  https://thetakeout.com/sur-la-table-bankruptcy...
# 38  https://www.forbes.com/sites/forbes-personal-s...
# 39  https://www.cnbc.com/2020/07/10/american-airli...
# 40  https://www.reuters.com/article/us-berkshire-b...
# 41  https://www.cnbc.com/2020/07/10/leveraged-and-...
# 42  https://www.fool.com/investing/2020/07/10/unit...
# 43  https://news.google.com/__i/rss/rd/articles/CB...
# 44  https://news.yahoo.com/looking-ahead-to-a-covi...
# 45  http://wgme.com/news/local/union-threatens-to-...
# 46  https://endpts.com/another-four-biotechs-scrat...
# 47  https://www.reuters.com/article/us-usa-economy...
# 48  https://www.wpxi.com/news/top-stories/parents-...
# 49  https://www.wkbw.com/news/local-news/1-278-nat...
#
#                                            urlToImage           publishedAt  \
# 0   https://bloximages.chicago2.vip.townnews.com/d...  2020-07-11T02:00:00Z
# 1   https://cdn.cnn.com/cnnnext/dam/assets/2003201...  2020-07-11T00:25:00Z
# 2   https://www.gannett-cdn.com/-mm-/1e50282dc070f...  2020-07-11T00:13:20Z
# 3   https://i.kinja-img.com/gawker-media/image/upl...  2020-07-11T00:10:00Z
# 4   https://www.oregonlive.com/resizer/pjarGAcVw1t...  2020-07-10T23:20:00Z
# 5   https://cnet3.cbsistatic.com/img/fiXO1pTD_I5pq...  2020-07-10T23:08:00Z
# 6   https://www.greeleytribune.com/wp-content/uplo...  2020-07-10T22:59:27Z
# 7   https://static2.seekingalpha.com/uploads/2020/...  2020-07-10T22:58:00Z
# 8   https://cdn.cnn.com/cnnnext/dam/assets/2006301...  2020-07-10T22:49:00Z
# 9   https://www.mercurynews.com/wp-content/uploads...  2020-07-10T22:39:00Z
# 10  https://www.ksat.com/resizer/4_9QNg1agIyhVEHD2...  2020-07-10T22:26:00Z
# 11  https://ichef.bbci.co.uk/news/1024/branded_new...  2020-07-10T21:52:43Z
# 12  https://media.npr.org/assets/img/2020/07/10/ge...  2020-07-10T21:48:53Z
# 13  https://a57.foxnews.com/static.foxbusiness.com...  2020-07-10T21:22:09Z
# 14  https://cdn.cnn.com/cnnnext/dam/assets/2007101...  2020-07-10T21:06:00Z
# 15  https://i2.wp.com/thepointsguy.com/wp-content/...  2020-07-10T21:02:02Z
# 16  https://image.cnbcfm.com/api/v1/image/10661135...  2020-07-10T20:16:00Z
# 17  https://cdn.benzinga.com/files/imagecache/og_i...  2020-07-10T20:08:39Z
# 18  https://image.cnbcfm.com/api/v1/image/10661111...  2020-07-10T19:53:00Z
# 19  https://cdn.cnn.com/cnnnext/dam/assets/2007091...  2020-07-10T19:51:00Z
# 20  https://image.cnbcfm.com/api/v1/image/10594045...  2020-07-10T19:22:00Z
# 21  http://static-25.sinclairstoryline.com/resourc...  2020-07-10T19:18:45Z
# 22  https://thumbor.forbes.com/thumbor/fit-in/1200...  2020-07-10T19:03:00Z
# 23  https://d32r1sh890xpii.cloudfront.net/article/...  2020-07-10T19:00:00Z
# 24  http://static-37.sinclairstoryline.com/resourc...  2020-07-10T18:57:00Z
# 25            https://images.wsj.net/im-208043/social  2020-07-10T18:45:00Z
# 26  https://s.marketwatch.com/public/resources/ima...  2020-07-10T18:40:00Z
# 27  https://g.foolcdn.com/editorial/images/581954/...  2020-07-10T18:34:00Z
# 28  https://cdn.vox-cdn.com/thumbor/dW3PvuXiW3LCt_...  2020-07-10T18:25:41Z
# 29  https://techcrunch.com/wp-content/uploads/2015...  2020-07-10T18:22:14Z
# 30  https://a57.foxnews.com/static.foxbusiness.com...  2020-07-10T18:10:00Z
# 31  https://s.yimg.com/uu/api/res/1.2/UkeGR986k_Mq...  2020-07-10T17:47:00Z
# 32  https://s3-ca-central-1.amazonaws.com/quincy-n...  2020-07-10T17:43:29Z
# 33  https://www.insidehook.com/wp-content/uploads/...  2020-07-10T17:09:51Z
# 34  https://www.investors.com/wp-content/uploads/2...  2020-07-10T16:55:00Z
# 35                                               None  2020-07-10T16:37:58Z
# 36  https://quincy-network.s3.ca-central-1.amazona...  2020-07-10T16:30:00Z
# 37  https://i.kinja-img.com/gawker-media/image/upl...  2020-07-10T16:28:00Z
# 38  https://thumbor.forbes.com/thumbor/fit-in/1200...  2020-07-10T16:15:00Z
# 39  https://image.cnbcfm.com/api/v1/image/10601169...  2020-07-10T16:08:00Z
# 40  https://s3.reutersmedia.net/resources/r/?m=02&...  2020-07-10T16:08:00Z
# 41  https://image.cnbcfm.com/api/v1/image/10460815...  2020-07-10T16:00:00Z
# 42  https://g.foolcdn.com/editorial/images/581892/...  2020-07-10T15:59:00Z
# 43                                               None  2020-07-10T15:57:00Z
# 44  https://s.yimg.com/ny/api/res/1.2/4NLD1liQPMI4...  2020-07-10T15:47:00Z
# 45  http://static-28.sinclairstoryline.com/resourc...  2020-07-10T15:25:00Z
# 46  https://endpts.com/wp-content/uploads/2020/05/...  2020-07-10T14:37:27Z
# 47  https://s2.reutersmedia.net/resources/r/?m=02&...  2020-07-10T14:30:00Z
# 48  https://d1hfln2sfez66z.cloudfront.net/07-10-20...  2020-07-10T14:15:09Z
# 49  https://ewscripps.brightspotcdn.com/dims4/defa...  2020-07-10T14:10:00Z
#
#                                               content
# 0   HUMMELS WHARF Two people are dead following a ...
# 1   (CNN)Three people have tested positive for cor...
# 2   A group of Five Guys employees who refused to ...
# 3   Well, which do you want first?\r\nLets start w...
# 4   MUJI U.S.A., a division of the Japanese retail...
# 5   Holy moly, does this thing look cool.\r\nBronc...
# 6   Employees of all levels reportedly walked off ...
# 7   After the Fed stress test results were release...
# 8                                                None
# 9   Santa Clara County will open new coronavirus t...
# 10  SAN ANTONIO At a time when people are stocking...
# 11  Image caption\r\n Emirates president Sir Tim C...
# 12  In 2005, Franklin Leonard was a junior executi...
# 13  Companies that contract with major U.S. cities...
# 14                                               None
# 15  Get ready for the Great Shrinking of the Fleet...
# 16  Even when the Great Recession dampened consume...
# 17  <ul><li>Electric truck and SUV maker Rivian ha...
# 18  Disney is facing a double-edged sword.\r\nShar...
# 19                                               None
# 20  Investors and traders have historically turned...
# 21  Ice cream is the comfort food of summer - and ...
# 22  null\r\nGetty\r\nMany unemployed and cash-stra...
# 23                                               None
# 24                                               None
# 25  The Federal Reserve bought about $1.3 billion ...
# 26  Shares of Gilead Sciences Inc. gained 2.0% on ...
# 27  BioNTech (NASDAQ:BNTX) and Pfizer(NYSE:PFE) ar...
# 28  Were unwanted Facebook text messages illegal?\...
# 29  After going private in 2016 after accepting a ...
# 30  While rewards credit cards continue to grow in...
# 31  (Bloomberg) -- The allure of electric vehicles...
# 32  SEATTLE (AP) A homeless shelter built on Amazo...
# 33  Were 30 years and a day away from Forbes publi...
# 34  The Dow Jones Industrial Average was up 200 po...
# 35                                               None
# 36  12:33 P.M. UPDATE:\r\n(WBNG) -- The Oakdale Ma...
# 37  Kitchenware retailer Sur La Table has filed fo...
# 38  Fitness and athleisure brand Lululemon is know...
# 39  American Airlines executives have told Boeing ...
# 40  (Reuters) - Berkshire Hathaway Inc has reduced...
# 41  Are leveraged and inverse exchange-traded fund...
# 42  United Airlines Holdings (NASDAQ:UAL) late Thu...
# 43                                               None
# 44  With the number of new cases of COVID-19 conti...
# 45                                               None
# 46  Four more biotechs are rais­ing their of­fers ...
# 47  WASHINGTON (Reuters) - U.S. producer prices un...
# 48  PITTSBURGH — A group of parents of children wi...
# 49  BUFFALO, N.Y. (WKBW) As Western New York enter...

# %%
# Extract the URL for each of the top headlines and the title
count = 0
for i in response_json['articles']:
    print(i['title'])
    print(i['url'])
    count = count + 1

print('Total number of articles: '+str(count))
# Out:
# UPDATE Two people reported dead; no threat to public; Monroe Marketplace evacuated - Sunbury Daily Item
# https://www.dailyitem.com/news/update-state-police-two-dead-after-shooting-no-threat-to-public/article_22b78758-c30a-11ea-a658-57cb54b1c099.html
# 3 people test positive for Covid-19 after taking Delta flight from Atlanta to Albany, airline says - CNN
# https://www.cnn.com/2020/07/10/us/delta-air-lines-coronavirus-passengers/index.html
# Five Guys says employees who refused to serve police have been fired, suspended - USA TODAY
# https://www.usatoday.com/story/money/food/2020/07/10/five-guys-fires-employees-after-they-refusing-police-service/5418419002/
# I Have Good News and Bad News About NBC's Streaming Service Peacock - Gizmodo
# https://gizmodo.com/i-have-good-news-and-bad-news-about-nbcs-streaming-serv-1844343727
# MUJI U.S.A. files for bankruptcy, blames coronavirus - OregonLive
# https://www.oregonlive.com/business/2020/07/muji-usa-files-for-bankruptcy-blames-coronavirus.html
# 2021 Ford Bronco leaks ahead of Monday's debut - CNET
# https://www.cnet.com/roadshow/news/2021-ford-bronco-leaked-photo/
# JBS employees walk off the job over pay dispute - Greeley Tribune
# https://www.greeleytribune.com/jbs-employees-walk-off-the-job-over-pay-dispute
# Wells Fargo: Fed Overreacts On Dividend Cut - Seeking Alpha
# https://seekingalpha.com/article/4357892-wells-fargo-fed-overreacts-on-dividend-cut
# Elon Musk just became richer than Warren Buffett - CNN
# https://www.cnn.com/2020/07/10/business/elon-musk-warren-buffett-billionaires/index.html
# Santa Clara County opening new free coronavirus test sites - The Mercury News
# https://www.mercurynews.com/santa-clara-county-opening-new-coronavirus-test-sites
# Two hand sanitizer brands recalled over methanol concerns - KSAT San Antonio
# https://www.ksat.com/news/local/2020/07/10/two-hand-sanitizer-brands-recalled-over-methanol-concerns/
# Emirates set to cut 9000 jobs, citing pandemic - BBC News
# https://www.bbc.com/news/business-53369463
# How Franklin Leonard and The Black List Changed Hollywood : Planet Money - NPR
# https://www.npr.org/2020/07/10/889708583/hollywoods-black-list
# Millions in PPP aid given to traffic camera companies linked to corruption scandals - Fox Business
# https://www.foxbusiness.com/economy/foreign-traffic-camera-companies-received-millions-in-ppp-aid
# Tyson and other meat processors are reportedly speeding up plans for robot butchers - CNN
# https://www.cnn.com/2020/07/10/business/tyson-meatpacking-plants-automation/index.html
# 13 cruise ships to be scrapped or sold as Carnival Corp. manages COVID fallout - The Points Guy
# http://thepointsguy.com/news/carnival-cruise-ships-sold-scrapped/
# Pandemic deals mightier blow to retail than Great Recession: First-quarter operating income down 58% - CNBC
# https://www.cnbc.com/2020/07/10/first-quarter-retail-industry-operating-income-falls-58percent.html
# Electric Truck Maker Rivian Secures $2.5B In New Financing - Benzinga
# https://www.benzinga.com/news/20/07/16591507/electric-truck-maker-rivian-secures-2-5b-in-new-financing
# Disney is still a buy, traders say, as Florida theme parks reopen amid rising coronavirus cases - CNBC
# https://www.cnbc.com/2020/07/10/disney-world-coronavirus-stock-a-buy-despite-reopening-traders-say.html
# Ford pressured to stop selling police cars, but it won't get out of the business - CNN
# https://www.cnn.com/2020/07/10/business/ford-police-car-sales-black-lives-matter-trnd/index.html
# Big Tech went from growth stocks to Wall Street's Treasury bond substitute during the coronavirus - CNBC
# https://www.cnbc.com/2020/07/10/big-tech-went-from-growth-stocks-to-wall-streets-treasury-bond-substitute-during-the-coronavirus.html
# The best ice cream in Seattle (and how to get it) - seattlerefined.com
# http://seattlerefined.com/eat-drink/the-best-ice-cream-in-seattle-and-how-to-get-it
# How College Students Can Get Nearly $800 A Week In Pandemic Unemployment Assistance, Backdated From April 2020 Through July 2020 - Forbes
# https://www.forbes.com/sites/reneemorad/2020/07/10/how-college-students-can-get-nearly-800-a-week-in-pandemic-unemployment-assistance-backdated-from-april-2020-through-july-2020/
# Oil Returns To $40 After COVID Correction - OilPrice.com
# https://oilprice.com/Energy/Energy-General/Oil-Returns-To-40-After-COVID-Correction.html
# Kroger won't give coins for change during shortage - WKRC TV Cincinnati
# http://local12.com/news/local/kroger-wont-give-coins-for-change-during-shortage
# Fed Discloses More Corporate Bond and ETF Purchases - The Wall Street Journal
# https://www.wsj.com/articles/fed-bought-about-1-3-billion-corporate-bonds-in-late-june-11594396039
# Gilead says coronavirus drug remdesivir can reduce risk of death, but analysts need more proof - MarketWatch
# https://www.marketwatch.com/story/gilead-says-coronavirus-drug-remdesivir-can-reduce-risk-of-death-but-analysts-need-more-proof-2020-07-10
# Pfizer and BioNTech's Coronavirus Vaccine Ready for Regulatory Submission in December, Maybe Earlier - The Motley Fool
# https://www.fool.com/investing/2020/07/10/pfizer-and-biontechs-coronavirus-vaccine-ready-for.aspx
# Supreme Court will hear Facebook robocalling case - The Verge
# https://www.theverge.com/2020/7/10/21320184/supreme-court-facebook-duguid-robocall-tcpa-class-action-lawsuit
# Rackspace preps IPO after going private in 2016 for $4.3B - TechCrunch
# http://techcrunch.com/2020/07/10/rackspace-preps-ipo-after-going-private-in-2016-for-4-3b/
# How do rewards credit cards work? - Fox Business
# https://www.foxbusiness.com/money/rewards-credit-cards
# Apollo-Backed Blank-Check Company Surges 71% on Possible Fisker Deal - Yahoo Finance
# https://finance.yahoo.com/news/apollo-backed-blank-check-company-145535304.html
# Amazon's homeless shelter faces Seattle crisis, criticism - KTIV
# https://ktiv.com/2020/07/10/amazons-homeless-shelter-faces-seattle-crisis-criticism/
# The Long, Slow Death of Brooks Brothers, An American Icon - InsideHook
# https://www.insidehook.com/article/menswear/long-slow-death-brooks-brothers
# Dow Jones Leads Market On Coronavirus Vaccine Hopes, But Nasdaq Slips Into Red - Investor's Business Daily
# https://www.investors.com/market-trend/stock-market-today/dow-jones-rallies-lead-stock-market-coronavirus-vaccine-near/
# Kids Shipped in Armoires? The Person Who Started the Wayfair Conspiracy Speaks - Newsweek
# https://news.google.com/__?oc=5
# Oakdale Mall to open July 20 - WBNG-TV
# http://wbng.com/2020/07/10/malls-open-across-state-but-oakdale-mall-remains-closed/
# Sur La Table bankruptcy means big liquidation sales - The Takeout
# https://thetakeout.com/sur-la-table-bankruptcy-means-big-liquidation-sales-1844337060
# The Lululemon Online Warehouse Sale You Don’t Want To Miss - Forbes
# https://www.forbes.com/sites/forbes-personal-shopper/2020/07/10/lululemon-warehouse-sale-what-to-buy/
# American Airlines tells Boeing: No financing, no 737 Max deliveries - CNBC
# https://www.cnbc.com/2020/07/10/american-airlines-tells-boeing-no-financing-no-737-max-deliveries.html
# Buffett's Berkshire Hathaway reduces share count, suggesting possible buybacks - Reuters
# https://www.reuters.com/article/us-berkshire-buffett-stock-idUSKBN24B2CZ
# Are leveraged and inverse ETFs worth the risk? Two industry pros break it down - CNBC
# https://www.cnbc.com/2020/07/10/leveraged-and-inverse-etfs-worth-the-risk-two-industry-pros-explain.html
# United Strikes Deal With Pilots on Buyouts, Early Retirements - The Motley Fool
# https://www.fool.com/investing/2020/07/10/united-strikes-deal-with-pilots-on-buyouts-early-r.aspx
# WASDE: Lower Corn Supplies on Due to Acreage Reduction - Agweb Powered by Farm Journal
# https://news.google.com/__i/rss/rd/articles/CBMiTWh0dHBzOi8vd3d3LmFnd2ViLmNvbS9hcnRpY2xlL3dhc2RlLWxvd2VyLWNvcm4tc3VwcGxpZXMtZHVlLWFjcmVhZ2UtcmVkdWN0aW9u0gEA?oc=5
# Looking ahead to a COVID vaccine: Who will make it? Who will receive it? How much will it cost? - Yahoo News
# https://news.yahoo.com/looking-ahead-to-a-covid-vaccine-who-will-make-it-who-will-receive-it-how-much-will-it-cost-154734127.html
# Union threatens to fine BIW workers if they cross picket line - WGME
# http://wgme.com/news/local/union-threatens-to-fine-biw-workers-if-they-cross-picket-line
# Another four biotechs scratch out the first number and ask for more as IPO boom continues - Endpoints News
# https://endpts.com/another-four-biotechs-scratch-out-the-first-number-and-ask-for-more-as-ipo-boom-continues/
# U.S. producer prices unexpectedly fall; underlying inflation stabilizing - Reuters
# https://www.reuters.com/article/us-usa-economy-idUSKBN24B226
# Group sues owners of Kennywood, Sandcastle, Idlewild parks over mask policy - WPXI Pittsburgh
# https://www.wpxi.com/news/top-stories/parents-sue-owners-kennywood-sandcastle-idlewild-parks-over-mask-policy/BDJKAZ5F6RBOZHBJ4PF5FPXG5A/
# 8,000 National Grid customers without power in North Buffalo, estimated restoration Saturday morning - WKBW-TV
# https://www.wkbw.com/news/local-news/1-278-national-grid-customers-without-power-in-north-buffalo-and-parts-of-northern-erie-county
# 3 Reasons to Buy Oil Stocks Right Now - Motley Fool
# https://www.fool.com/investing/2020/07/10/3-reasons-to-buy-oil-stocks-right-now.aspx
# Insights on the Public Cloud Global Market to 2026 - Featuring IBM, Amazon & Salesforce Among Others - Benzinga
# https://www.benzinga.com/pressreleases/20/07/g16584517/insights-on-the-public-cloud-global-market-to-2026-featuring-ibm-amazon-salesforce-among-others
# United Airlines plans to furlough 450 employees at Cleveland Hopkins International Airport - WJW FOX 8 News Cleveland
# https://fox8.com/news/united-airlines-plans-to-furlough-450-employees-at-cleveland-hopkins-international-airport/
# The union battle versus Trump administration over bringing workers back, safely - CNBC
# https://www.cnbc.com/2020/07/10/as-workplaces-reopen-unions-ask-trump-admin-where-is-osha.html
# Bed Bath & Beyond plans to close 200 stores over the next two years - WJW FOX 8 News Cleveland
# https://fox8.com/news/coronavirus/bed-bath-beyond-plans-to-close-200-stores-over-the-next-two-years/
# Current Refinance Rates, July 10, 2020 | Rates retreat - Bankrate.com
# https://www.bankrate.com/mortgages/rates/refinance-rates-for-friday-july-10-2020/
# PC shipments surge as the world gets serious about working from home - The Verge
# https://www.theverge.com/2020/7/10/21319750/pc-shipments-coronavirus-pandemic-idc-gartner-q2-2020
# Is the party finally over for US oil and gas? - Financial Times
# https://www.ft.com/content/e9e0ce5d-3bc0-45dd-9b7c-54b0828b9e99
# First Seattle volunteer in human COVID-19 vaccine trials says she feels 'fantastic' - KOMO News
# http://komonews.com/news/coronavirus/first-seattle-volunteer-in-human-covid-19-vaccine-trials-says-she-feels-fantastic
# Wall Street rallies as optimism returns to cap erratic week - The Associated Press
# https://apnews.com/e3fe25aabbfc1fee055b0e14e7708cfa
# Coronavirus: Lysol, Clorox, Microban 24 kills COVID-19, EPA says - Deseret News
# https://www.deseret.com/u-s-world/2020/7/9/21318587/coronavirus-lysol-clorox-microban-24-kill-covid-19
# Starbucks requiring all U.S. customers to wear masks starting July 15 - CBS News
# https://www.cbsnews.com/news/starbucks-face-masks-required-customers-july-15/
# No new restrictions in Beaver County as cases rise; Allegheny County changes orders - The Times
# https://www.timesonline.com/article/20200709/NEWS/200709145
# Coronavirus canceled office clothing. These stores are in big trouble - CNN
# https://www.cnn.com/2020/07/08/business/office-wear-dead-brooks-brothers/index.html
# Harley-Davidson’s ‘Rewire’ plan starts with 700 jobs cuts, ousted CFO - TechCrunch
# http://techcrunch.com/2020/07/09/harley-davidsons-rewire-plan-starts-with-700-jobs-cuts-ousted-cfo/
# Drug Giants Create Fund to Bolster Struggling Antibiotic Start-Ups - The New York Times
# https://www.nytimes.com/2020/07/09/health/antibiotics-pharma-drug-resistance.html
# Researchers say CBD could provide vital treatment for coronavirus - Chicago Tribune
# https://www.chicagotribune.com/marijuana/sns-tft-cbd-coronavirus-treatment-research-20200709-4gp2a2w76fah7p277n3ss42yby-story.html
# Find Out Who Got a PPP Loan with ProPublica's New Tool - Lifehacker
# https://lifehacker.com/find-out-who-got-a-ppp-loan-with-propublicas-new-tool-1844324044
# Exclusive: Denver-based tech company announces employees will work from home permanently - Denver Business Journal
# https://www.bizjournals.com/denver/news/2020/07/09/visible-permanent-work-from-home-denver.html
# Walgreens swings to a quarterly loss as coronavirus drives up costs, lowers doctor visits; shares fall - CNBC
# https://www.cnbc.com/2020/07/09/walgreens-wba-earnings-q3-2020.html
# Total number of articles: 70

# %%
headline_urls = df['url']
print(headline_urls)
# Out:
# 0     https://www.dailyitem.com/news/update-state-po...
# 1     https://www.cnn.com/2020/07/10/us/delta-air-li...
# 2     https://www.usatoday.com/story/money/food/2020...
# 3     https://gizmodo.com/i-have-good-news-and-bad-n...
# 4     https://www.oregonlive.com/business/2020/07/mu...
#                             ...
# 65    https://www.nytimes.com/2020/07/09/health/anti...
# 66    https://www.chicagotribune.com/marijuana/sns-t...
# 67    https://lifehacker.com/find-out-who-got-a-ppp-...
# 68    https://www.bizjournals.com/denver/news/2020/0...
# 69    https://www.cnbc.com/2020/07/09/walgreens-wba-...
# Name: url, Length: 70, dtype: object

# %% [markdown]
# # Trying to use the newsdatascraper package
# from newsdatascraper import Scraper
#
# new_scraper = Scraper(secret, mode = 'NEWSPAPER')
# articles = new_scraper.fetch_all_articles("2020-07-07&language=en", page_size = 100)

# %% [markdown]
# # helper functions to serialize the data
#
# articles.to_csv('test.csv')
# #articles.toPickle('test.pickle')
# #articles.toJson()

# %% [markdown]
# # Extract the complete article text and and the NLP summary, for each of the top headline using the URL collected above
# from newspaper import Article
# from newspaper import Config
#
#
# article_title = []
# article_authors = []
# article_text = []
# article_summary = []
# article_date = []
# article_top_image = []
#
# for h in headline_urls:
# #news_article = Article(url=h)
#
#     news_article = Article(url=h)
#     try:
#         news_article.download()
#         #print(first_article.html)
#         news_article.parse()
#         news_article.nlp()
#     except newspaper.article.ArticleException:
#         print("Unable to download the article")
#         pass
#     article_title = news_article.title
#     #print(article_title)
#     article_authors = news_article.title
#     #print(article_authors)
#     article_text.append(news_article.text)
#     print(news_article.text)
#
#     article_summary.append(news_article.summary)
#     print(news_article.summary)
#     article_publish_date = news_article.publish_date
#     #print(article_publish_date)
#     article_top_image = news_article.top_image
#     #print(article_top_image)

# %%
# Extract the complete article text and and the NLP summary, for each of the top headline using the URL collected above
from newspaper import Article
from newspaper import Config
from summarizer import Summarizer

article_title = []
article_authors = []
article_text = []
article_summary = []
article_date = []
article_top_image = []
failed_url = []
full_summary = []
for h in headline_urls:
        user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
        config = Config()
        config.browser_user_agent = user_agent
        page = Article(h, config=config)
        try :
            page.download()
            page.parse()
            page.nlp()
            article_text.append(page.text)
            #print(page.text)
            #article_summary.append(page.summary)
            #print(page.summary)
            model = Summarizer()
            result = model(page.text, min_length=60)
            full_summary = ''.join(result)
            article_summary.append(full_summary)
            #print(full_summary)
        except :
            failed_url = h
            print(failed_url)
            df = df[df.url != failed_url]
            pass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-ba90e1ced162> in <module>
#       1 # Extract the complete article text and and the NLP summary, for each of the top headline using the URL collected above
# ----> 2 from newspaper import Article
#       3 from newspaper import Config
#       4 from summarizer import Summarizer
#       5
#
# ModuleNotFoundError: No module named 'newspaper'

# %%
# Drop the row(s) in the dataframe containing the URL that failed to download
print(df.shape)
# Out:
# (70, 10)

# %%
# Create new columns in dataframe to for the text and summary of the article
df['articleText'] = article_text
df['articleSummary'] = article_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-639b4f41fa67> in <module>
#       1 # Create new columns in dataframe to for the text and summary of the article
# ----> 2 df['articleText'] = article_text
#       3 df['articleSummary'] = article_summary
#
# NameError: name 'article_text' is not defined

# %%
print(df.head())
# Out:
#   status  totalResults                                      source  \
# 0     ok            70  {'id': None, 'name': 'Sunbury Daily Item'}
# 1     ok            70                {'id': 'cnn', 'name': 'CNN'}
# 2     ok            70    {'id': 'usa-today', 'name': 'USA Today'}
# 3     ok            70         {'id': None, 'name': 'Gizmodo.com'}
# 4     ok            70          {'id': None, 'name': 'OregonLive'}
#
#                                        author  \
# 0  Francis Scarcella fscarcella@dailyitem.com
# 1         Lauren del Valle and Amir Vera, CNN
# 2                                 Josh Rivera
# 3                                  Catie Keck
# 4                The Oregonian/OregonLive.com
#
#                                                title  \
# 0  UPDATE Two people reported dead; no threat to ...
# 1  3 people test positive for Covid-19 after taki...
# 2  Five Guys says employees who refused to serve ...
# 3  I Have Good News and Bad News About NBC's Stre...
# 4  MUJI U.S.A. files for bankruptcy, blames coron...
#
#                                          description  \
# 0  HUMMELS WHARF — Two people are dead following ...
# 1  The airline says it is following the guidance ...
# 2  A group of Five Guys employees who refused to ...
# 3                     Well, which do you want first?
# 4  The retail outlet has a Portland store, which ...
#
#                                                  url  \
# 0  https://www.dailyitem.com/news/update-state-po...
# 1  https://www.cnn.com/2020/07/10/us/delta-air-li...
# 2  https://www.usatoday.com/story/money/food/2020...
# 3  https://gizmodo.com/i-have-good-news-and-bad-n...
# 4  https://www.oregonlive.com/business/2020/07/mu...
#
#                                           urlToImage           publishedAt  \
# 0  https://bloximages.chicago2.vip.townnews.com/d...  2020-07-11T02:00:00Z
# 1  https://cdn.cnn.com/cnnnext/dam/assets/2003201...  2020-07-11T00:25:00Z
# 2  https://www.gannett-cdn.com/-mm-/1e50282dc070f...  2020-07-11T00:13:20Z
# 3  https://i.kinja-img.com/gawker-media/image/upl...  2020-07-11T00:10:00Z
# 4  https://www.oregonlive.com/resizer/pjarGAcVw1t...  2020-07-10T23:20:00Z
#
#                                              content
# 0  HUMMELS WHARF Two people are dead following a ...
# 1  (CNN)Three people have tested positive for cor...
# 2  A group of Five Guys employees who refused to ...
# 3  Well, which do you want first?\r\nLets start w...
# 4  MUJI U.S.A., a division of the Japanese retail...

# %%
df.get_value(0, 'articleText')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d8208d697aaa> in <module>
# ----> 1 df.get_value(0, 'articleText')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_value'

# %%
df.get_value(0, 'articleSummary')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1cf99782fc23> in <module>
# ----> 1 df.get_value(0, 'articleSummary')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_value'

# %%
json = df.to_json() 
print(json)
# Out:
# {"status":{"0":"ok","1":"ok","2":"ok","3":"ok","4":"ok","5":"ok","6":"ok","7":"ok","8":"ok","9":"ok","10":"ok","11":"ok","12":"ok","13":"ok","14":"ok","15":"ok","16":"ok","17":"ok","18":"ok","19":"ok","20":"ok","21":"ok","22":"ok","23":"ok","24":"ok","25":"ok","26":"ok","27":"ok","28":"ok","29":"ok","30":"ok","31":"ok","32":"ok","33":"ok","34":"ok","35":"ok","36":"ok","37":"ok","38":"ok","39":"ok","40":"ok","41":"ok","42":"ok","43":"ok","44":"ok","45":"ok","46":"ok","47":"ok","48":"ok","49":"ok","50":"ok","51":"ok","52":"ok","53":"ok","54":"ok","55":"ok","56":"ok","57":"ok","58":"ok","59":"ok","60":"ok","61":"ok","62":"ok","63":"ok","64":"ok","65":"ok","66":"ok","67":"ok","68":"ok","69":"ok"},"totalResults":{"0":70,"1":70,"2":70,"3":70,"4":70,"5":70,"6":70,"7":70,"8":70,"9":70,"10":70,"11":70,"12":70,"13":70,"14":70,"15":70,"16":70,"17":70,"18":70,"19":70,"20":70,"21":70,"22":70,"23":70,"24":70,"25":70,"26":70,"27":70,"28":70,"29":70,"30":70,"31":70,"32":70,"33":70,"34":70,"35":70,"36":70,"37":70,"38":70,"39":70,"40":70,"41":70,"42":70,"43":70,"44":70,"45":70,"46":70,"47":70,"48":70,"49":70,"50":70,"51":70,"52":70,"53":70,"54":70,"55":70,"56":70,"57":70,"58":70,"59":70,"60":70,"61":70,"62":70,"63":70,"64":70,"65":70,"66":70,"67":70,"68":70,"69":70},"source":{"0":{"id":null,"name":"Sunbury Daily Item"},"1":{"id":"cnn","name":"CNN"},"2":{"id":"usa-today","name":"USA Today"},"3":{"id":null,"name":"Gizmodo.com"},"4":{"id":null,"name":"OregonLive"},"5":{"id":null,"name":"CNET"},"6":{"id":null,"name":"Greeley Tribune"},"7":{"id":null,"name":"Seeking Alpha"},"8":{"id":"cnn","name":"CNN"},"9":{"id":null,"name":"The Mercury News"},"10":{"id":null,"name":"KSAT San Antonio"},"11":{"id":null,"name":"BBC News"},"12":{"id":null,"name":"NPR"},"13":{"id":null,"name":"Fox Business"},"14":{"id":"cnn","name":"CNN"},"15":{"id":null,"name":"The Points Guy"},"16":{"id":null,"name":"CNBC"},"17":{"id":null,"name":"Benzinga"},"18":{"id":null,"name":"CNBC"},"19":{"id":"cnn","name":"CNN"},"20":{"id":null,"name":"CNBC"},"21":{"id":null,"name":"seattlerefined.com"},"22":{"id":null,"name":"Forbes"},"23":{"id":null,"name":"OilPrice.com"},"24":{"id":null,"name":"WKRC TV Cincinnati"},"25":{"id":"the-wall-street-journal","name":"The Wall Street Journal"},"26":{"id":null,"name":"MarketWatch"},"27":{"id":null,"name":"Motley Fool"},"28":{"id":"the-verge","name":"The Verge"},"29":{"id":"techcrunch","name":"TechCrunch"},"30":{"id":null,"name":"Fox Business"},"31":{"id":null,"name":"Yahoo Entertainment"},"32":{"id":null,"name":"KTIV"},"33":{"id":null,"name":"InsideHook"},"34":{"id":null,"name":"Investor's Business Daily"},"35":{"id":"google-news","name":"Google News"},"36":{"id":null,"name":"WBNG-TV"},"37":{"id":null,"name":"The Takeout"},"38":{"id":null,"name":"Forbes"},"39":{"id":null,"name":"CNBC"},"40":{"id":"reuters","name":"Reuters"},"41":{"id":null,"name":"CNBC"},"42":{"id":null,"name":"Motley Fool"},"43":{"id":"google-news","name":"Google News"},"44":{"id":null,"name":"Yahoo Entertainment"},"45":{"id":null,"name":"WGME"},"46":{"id":null,"name":"Endpoints News"},"47":{"id":"reuters","name":"Reuters"},"48":{"id":null,"name":"WPXI Pittsburgh"},"49":{"id":null,"name":"WKBW-TV"},"50":{"id":null,"name":"Motley Fool"},"51":{"id":null,"name":"Benzinga"},"52":{"id":null,"name":"fox8.com"},"53":{"id":null,"name":"CNBC"},"54":{"id":null,"name":"fox8.com"},"55":{"id":null,"name":"Bankrate.com"},"56":{"id":"the-verge","name":"The Verge"},"57":{"id":"financial-times","name":"Financial Times"},"58":{"id":null,"name":"KOMO News"},"59":{"id":"associated-press","name":"Associated Press"},"60":{"id":null,"name":"Deseret News"},"61":{"id":"cbs-news","name":"CBS News"},"62":{"id":null,"name":"Timesonline.com"},"63":{"id":"cnn","name":"CNN"},"64":{"id":"techcrunch","name":"TechCrunch"},"65":{"id":null,"name":"New York Times"},"66":{"id":null,"name":"Chicago Tribune"},"67":{"id":null,"name":"Lifehacker.com"},"68":{"id":null,"name":"Triangle Business Journal"},"69":{"id":null,"name ...

# %%
# Write the dataframe to a json file with orient set to index
df.to_json('daily_news_data/JSON/top_headline_business_data.json', orient='index')

# %%
# Write the dataframe to a csv file with index set to false
df.to_csv('daily_news_data/CSV/top_headline_business_data.csv', index=False)

# %%
df.head()
# Out:
#   status  totalResults                                      source  \
# 0     ok            70  {'id': None, 'name': 'Sunbury Daily Item'}
# 1     ok            70                {'id': 'cnn', 'name': 'CNN'}
# 2     ok            70    {'id': 'usa-today', 'name': 'USA Today'}
# 3     ok            70         {'id': None, 'name': 'Gizmodo.com'}
# 4     ok            70          {'id': None, 'name': 'OregonLive'}
#
#                                        author  \
# 0  Francis Scarcella fscarcella@dailyitem.com
# 1         Lauren del Valle and Amir Vera, CNN
# 2                                 Josh Rivera
# 3                                  Catie Keck
# 4                The Oregonian/OregonLive.com
#
#                                                title  \
# 0  UPDATE Two people reported dead; no threat to ...
# 1  3 people test positive for Covid-19 after taki...
# 2  Five Guys says employees who refused to serve ...
# 3  I Have Good News and Bad News About NBC's Stre...
# 4  MUJI U.S.A. files for bankruptcy, blames coron...
#
#                                          description  \
# 0  HUMMELS WHARF — Two people are dead following ...
# 1  The airline says it is following the guidance ...
# 2  A group of Five Guys employees who refused to ...
# 3                     Well, which do you want first?
# 4  The retail outlet has a Portland store, which ...
#
#                                                  url  \
# 0  https://www.dailyitem.com/news/update-state-po...
# 1  https://www.cnn.com/2020/07/10/us/delta-air-li...
# 2  https://www.usatoday.com/story/money/food/2020...
# 3  https://gizmodo.com/i-have-good-news-and-bad-n...
# 4  https://www.oregonlive.com/business/2020/07/mu...
#
#                                           urlToImage           publishedAt  \
# 0  https://bloximages.chicago2.vip.townnews.com/d...  2020-07-11T02:00:00Z
# 1  https://cdn.cnn.com/cnnnext/dam/assets/2003201...  2020-07-11T00:25:00Z
# 2  https://www.gannett-cdn.com/-mm-/1e50282dc070f...  2020-07-11T00:13:20Z
# 3  https://i.kinja-img.com/gawker-media/image/upl...  2020-07-11T00:10:00Z
# 4  https://www.oregonlive.com/resizer/pjarGAcVw1t...  2020-07-10T23:20:00Z
#
#                                              content
# 0  HUMMELS WHARF Two people are dead following a ...
# 1  (CNN)Three people have tested positive for cor...
# 2  A group of Five Guys employees who refused to ...
# 3  Well, which do you want first?\r\nLets start w...
# 4  MUJI U.S.A., a division of the Japanese retail...

# %%
#df.to_csv('article_business_text.csv', columns=['articleText'],index=False)
